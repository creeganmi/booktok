# %%
import pandas as pd
import numpy as np
import itertools

# %% [markdown]
# ### Catalog cleaning data

# %%
# import catalog data 
df_cat = pd.read_csv('C:/Users/creeg/Downloads/adbl_catalog_cleaned (1).csv')
del df_cat["Unnamed: 0"] # delete unnecessary index column saved from scraping

# %%
df_cat.head()
# Out:
#   product_asin                                product_short_title  \
# 0   B07S64NL7C                      Overcoming Anger (Unabridged)
# 1   B00PMESE5C  Mouth Watering Super Shred Diet Recipes (Unabr...
# 2   B09TG64J8C                    Elite Productivity (Unabridged)
# 3   B08FRK6G4M                            The Tatars (Unabridged)
# 4   B07YGX7YGJ  1001 Questions to Help Flesh Out Your Characte...
#
#           product_author release_date  rating  rating_count  \
# 0             Bubba Hemp   2019-05-23     3.5             2
# 1           Alex Grayson   2014-11-17     2.0             1
# 2              BAB Group   2022-02-28     0.0             0
# 3  Charles River Editors   2020-08-12     5.0             1
# 4    Christina Escamilla   2019-09-28     0.0             0
#
#                                       legacy_genre
# 0                             Education & Learning
# 1                                Health & Wellness
# 2  Relationships, Parenting & Personal Development
# 3                                          History
# 4                                              NaN

# %%
# clean titles, make lowercase, removing things like 'unabridged', and strip, punctuation, extra whitespace
df_cat['product_short_title'] = df_cat['product_short_title'].str.lower()
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\(unabridged\)", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\(abridged\)", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 1", "").str.strip()
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 2", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 3", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 4", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 5", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 6", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 7", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 8", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 9", "").str.strip() 
df_cat["product_short_title"] = df_cat["product_short_title"].replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\n',  ' ', regex=True)
# Out:
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\(unabridged\)", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\(abridged\)", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 1", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 2", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 3", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 4", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 5", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 6", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 7", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 8", "").str.strip()
# C:\Users\creeg\AppData\Local\Temp/ipykernel_17720/3045902568.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat["product_short_title"] = df_cat["product_short_title"].str.replace("\, book 9", "").str.strip()

# %%
# create list of titles that are the exception to "one word title exclusion" rule 

one_word_exceptions = ['1797113461','1713570874','1789999103','B08VYFG11M','B08S622QNT','1800263686','B08V4MTZTP','1526622416','B08YFM1565','593459296','593212142','1529342015','593168070','B08B46CK1J','B08J8BJV3T','B082MQ5TDB','1774243326','B086WNG3RK','B086WMZ9WR','1774246325','593294181']

# %% [markdown]
# ### add a whitespace count to titles and remove one word titles that were:
# 1. released before April 2020 (not released in last 2 years)
# 2. have fewer than 1K ratings (assume this is indicative of low popularity/sales)

# %%
# remove titles with length less than or equal to 3 characters (this removes titles like "Y" "X" "Her") 
# titles like this are too difficult to identify via string matching, we'd rather underassign tweets that are about 
# these titles than overassin tweets that don't contain titles but do contain the word "her" or letter "y"
import datetime

# set date to 2 years ago and convert release date column to datetime
date_before = datetime.datetime(2020, 4, 1)
df_cat['release_date'] = pd.to_datetime(df_cat['release_date'])

# add a column that counts number of spaces in title 
df_cat['whitespace_ct'] = df_cat['product_short_title'].str.count(' ')

# print catalog size before dropping records
print(str(len(df_cat))+' titles before dropping records') 

# remove titles < 3 characters
df_cat.drop(df_cat[df_cat['product_short_title'].map(len) <= 3].index, inplace=True)

# keep only titles with at least 1 space (i.e. 2 words) or that appear in the exception list
df_cat = df_cat.loc[((df_cat['whitespace_ct'] > 0) | (df_cat['product_asin'].isin(one_word_exceptions)))]

# drop titles with fewer than 10 ratings - consider this a proxy for sales 
df_cat.drop(df_cat[df_cat['rating_count'] < 10].index, inplace=True)

# print catalog size before dropping records

print(str(len(df_cat))+' titles after dropping records')
# Out:
# 518540 titles before dropping records
# 203319 titles after dropping records

# %%
# sort catalog df by # of ratings - enteries are ordered in the dictionary by order of insertion
# this ensures that for titles that exist as substrings of other titles (ex: Raw is contained in Where the Crawdad's Sing)
# the most popular title (based on rating count) will get assigned to a tweet first 
df_cat = df_cat.sort_values(by=['rating_count'],ascending=False)

# %%
# duplicate title column removing spaces
# this will allow us to identify titles that may have been used as hashtags rather than fully named in the tweet
df_cat["title_no_spaces"] = df_cat["product_short_title"].str.replace(" ", "").str.strip()

# %%
df_cat.head()
# Out:
#        product_asin                    product_short_title  \
# 149211   B07FSNSLZ1                where the crawdads sing
# 28988    B01I28NFEE    the subtle art of not giving a f*ck
# 308431   B07KKMNZCH                          can't hurt me
# 445593   B017V4IM1G  harry potter and the sorcerer's stone
# 159139   B002UZZ93G                      a game of thrones
#
#             product_author release_date    rating  rating_count  \
# 149211         Delia Owens   2018-08-14  4.760701        193799
# 28988          Mark Manson   2016-09-13  4.516414        144510
# 308431       David Goggins   2018-11-28  4.874660        139548
# 445593        J.K. Rowling   2015-11-20  4.903521        139222
# 159139  George R.R. Martin   2003-12-09  4.757246        128418
#
#                                            legacy_genre  whitespace_ct  \
# 149211                                          Romance              3
# 28988   Relationships, Parenting & Personal Development              7
# 308431  Relationships, Parenting & Personal Development              2
# 445593                        Science Fiction & Fantasy              5
# 159139                             Literature & Fiction              3
#
#                          title_no_spaces
# 149211              wherethecrawdadssing
# 28988       thesubtleartofnotgivingaf*ck
# 308431                       can'thurtme
# 445593  harrypotterandthesorcerer'sstone
# 159139                    agameofthrones

# %%
# merge both title columns into a list, this list will become the value in the catalog dictionary
df_cat["both_titles"] = list(zip(df_cat['product_short_title'], df_cat['title_no_spaces']))

# %%
# convert the catalog asin (unique identifier) & title list into a dictionary 
cat_dict = df_cat.set_index('product_asin').to_dict()['both_titles']

# %%
cat_dict
# Out:
# {'B07FSNSLZ1': ('where the crawdads sing', 'wherethecrawdadssing'),
#  'B01I28NFEE': ('the subtle art of not giving a f*ck',
#   'thesubtleartofnotgivingaf*ck'),
#  'B07KKMNZCH': ("can't hurt me", "can'thurtme"),
#  'B017V4IM1G': ("harry potter and the sorcerer's stone",
#   "harrypotterandthesorcerer'sstone"),
#  'B002UZZ93G': ('a game of thrones', 'agameofthrones'),
#  'B017V4IWVG': ('harry potter and the chamber of secrets',
#   'harrypotterandthechamberofsecrets'),
#  'B002UZMLXM': ('the name of the wind', 'thenameofthewind'),
#  'B017V4JA2Q': ('harry potter and the prisoner of azkaban',
#   'harrypotterandtheprisonerofazkaban'),
#  'B017V4NUPO': ('harry potter and the goblet of fire',
#   'harrypotterandthegobletoffire'),
#  'B003ZWFO7E': ('the way of kings', 'thewayofkings'),
#  'B002UZKIBO': ('a clash of kings', 'aclashofkings'),
#  'B017V4NMX4': ('harry potter and the order of the phoenix',
#   'harrypotterandtheorderofthephoenix'),
#  'B06Y1GBY2M': ('before we were yours', 'beforewewereyours'),
#  'B0731R4RFX': ('unfu*k yourself', 'unfu*kyourself'),
#  'B017V4NOZ0': ('harry potter and the half-blood prince',
#   'harrypotterandthehalf-bloodprince'),
#  'B004QISZN6': ("the wise man's fear", "thewiseman'sfear"),
#  'B01KKPH1VA': ('the dispatcher', 'thedispatcher'),
#  'B0797YBP7N': ('12 rules for life', '12rulesforlife'),
#  'B0036NQ9Z8': ('a storm of swords', 'astormofswords'),
#  'B002V0QCYU': ('the final empire: mistborn book 1',
#   'thefinalempire:mistbornbook1'),
#  'B008BT3C1Q': ('rich dad poor dad', 'richdadpoordad'),
#  'B00HWF0MHW': ('words of radiance', 'wordsofradiance'),
#  '1705015328': ('outlander: international edition',
#   'outlander:internationaledition'),
#  'B007C64916': ('the power of habit', 'thepowerofhabit'),
#  'B015TVHUA2': ('extreme ownership', 'extremeownership'),
#  'B01LWUJKQ7': ('norse mythology', 'norsemythology'),
#  '1549150340': ('talking to strangers', 'talkingtostrangers'),
#  'B077H1PRL8': ('girl, wash your face', 'girl,washyourface'),
#  'B06XYT3G6M': ('eleanor oliphant is completely fine',
#   'eleanoroliphantiscompletelyfine'),
#  'B0077DEH7A': ('the stand', 'thestand'),
#  'B07BQFXFW9': ('then she was gone', 'thenshewasgone'),
#  'B00YNT5JO6': ('the life we bury', 'thelifewebury'),
#  '1250317533': ('the silent patient', 'thesilentpatient'),
#  'B0055274U2': ('american gods: the tenth anniversary edition (a full cast production)',
#   'americangods:thetenthanniversaryedition(afullcastproduction)'),
#  'B0085XRNWM': ('gone girl', 'gonegirl'),
#  'B0099RKI5W': ('the hobbit', 'thehobbit'),
#  'B07957SPGB': ('the outsider', 'theoutsider'),
#  'B00UX8ODPM': ('elon musk', 'elonmusk'),
#  'B0057POQJE': ('a dance with dragons', 'adancewithdragons'),
#  'B01GW1OHVI': ('behind closed doors', 'behindcloseddoors'),
#  'B0099RKRTY': ('the fellowship of the ring', 'thefellowshipofthering'),
#  'B00K8F589A': ('big little lies', 'biglittlelies'),
#  'B002VA9IKK': ('the hero of ages', 'theheroofages'),
#  'B01CF5O89G': ('never split the difference', 'neversplitthedifference'),
#  'B002V5GLQ4': ('the well of ascension', 'thewellofascension'),
#  'B01EM4ZO14': ('hillbilly elegy', 'hillbillyelegy'),
#  'B006LPIVL8': ('a feast for crows', 'afeastforcrows'),
#  'B00I2VWW5U': ('red rising', 'redrising'),
#  'B002V8KYMI': ('storm front', 'stormfront'),
#  'B002VA9SWS': ("the hitchhiker's guide to the galaxy",
#   "thehitchhiker'sguidetothegalaxy"),
#  '0593396960': ('ready player two', 'readyplayertwo'),
#  'B01NAGD7TV': ('the hate u give', 'thehateugive'),
#  'B06VX22V89': ('the 5 second rule', 'the5secondrule'),
#  '0062963708': ('the dutch house', 'thedutchhouse'),
#  'B01CRM17MS': ('shoe dog', 'shoedog'),
#  'B07CRQQHG2': ('something in the water', 'somethinginthewater'),
#  'B06Y4FV56S': ('the alice network', 'thealicenetwork'),
#  'B002V1CN0G': ('dragonfly in amber', 'dragonflyinamber'),
#  'B005DF6XHQ': ('the 10x rule', 'the10xrule'),
#  'B06XS3VMBM': ('beneath a scarlet sky', 'beneathascarletsky'),
#  'B004MNLNX4': ('a discovery of witches', 'adiscoveryofwitches'),
#  'B06ZXT7Z51': ('the great alone', 'thegreatalone'),
#  'B002UZMWNG': ('the girl with the dragon tattoo',
#   'thegirlwiththedragontattoo'),
#  '0525530207': ('the giver of stars', 'thegiverofstars'),
#  'B002UUKIR8': ('the total money makeover', 'thetotalmoneymakeover'),
#  '0525633723': ('a promised land', 'apromisedland'),
#  '1705015336': ('dragonfly in amber: international edition',
#   'dragonflyinamber:internationaledition'),
#  'B009ABHTF4': ('the two towers', 'thetwotowers'),
#  'B01N48VJFJ': ('columbus day', 'columbusday'),
#  'B0036KV7Y4': ('good omens', 'goodomens'),
#  'B002V1NTTU': ('sharp objects', 'sharpobjects'),
#  'B00R6S1RCY': ('golden son', 'goldenson'),
#  'B002VA3GJO': ('the four agreements', 'thefouragreements'),
#  'B019NMZ6FE': ('morning star', 'morningstar'),
#  '1508279071': ('the institute', 'theinstitute'),
#  'B007QV7C5W': ('fifty shades of grey', 'fiftyshadesofgrey'),
#  'B002V08BS0': ('drums of autumn', 'drumsofautumn'),
#  'B07C8GVTB5': ('bad blood', 'badblood'),
#  'B00J8VK1WY': ('mr. mercedes', 'mr.mercedes'),
#  'B00WX7Y0W2': ('the last wish', 'thelastwish'),
#  'B07NLL95S4': ('maybe you should talk to someone',
#   'maybeyoushouldtalktosomeone'),
#  'B00D3PBYAE': ('the boys in the boat', 'theboysintheboat'),
#  'B002V5HAL4': ('the 7 habits of highly effective people',
#   'the7habitsofhighlyeffectivepeople'),
#  'B06X9MXN32': ('astrophysics for people in a hurry',
#   'astrophysicsforpeopleinahurry'),
#  'B00CS522EW': ("the cuckoo's calling", "thecuckoo'scalling"),
#  '170501531X': ('drums of autumn: international edition',
#   'drumsofautumn:internationaledition'),
#  'B00DEL0Z9I': ('doctor sleep', 'doctorsleep'),
#  'B002V0GGFK': ('the five love languages: the secret to love that lasts',
#   'thefivelovelanguages:thesecrettolovethatlasts'),
#  'B002UP1LXS': ('the great hunt', 'thegreathunt'),
#  'B07XQLXGJW': ('midnight son', 'midnightson'),
#  'B002V0QUOC': ("man's search for meaning", "man'ssearchformeaning"),
#  'B019NNU7XE': ('the dark tower i', 'thedarktoweri'),
#  'B07W8WY88T': ('the sisters', 'thesisters'),
#  'B075NMRZTR': ('black ops', 'blackops'),
#  'B074Q1R3VB': ('the wife between us', 'thewifebetweenus'),
#  '1797113860': ('too much and never enough', 'toomuchandneverenough'),
#  'B078RV7BWR': ('zero hour', 'zerohour'),
#  'B00UKEQK82': ('modern romance', 'modernromance'),
#  'B002V1BII4': ('fool moon', 'foolmoon'),
#  'B08129DD1H': ('buried deep', 'burieddeep'),
#  'B002UZYX2Y': ('the pillars of the earth', 'thepillarsoftheearth'),
#  'B008OLF29Q': ('the shining', 'theshining'),
#  'B002V0PN36': ('the power of now', 'thepowerofnow'),
#  'B00RC3M6OG': ('the life-changing magic of tidying up',
#   'thelife-changingmagicoftidyingup'),
#  'B002V8LF30': ('the girl who played with fire', 'thegirlwhoplayedwithfire'),
#  'B005V0QI82': ('steve jobs', 'stevejobs'),
#  'B071Y9TTHC': ('children of time', 'childrenoftime'),
#  'B00IIS32NI': ('off to be the wizard', 'offtobethewizard'),
#  'B071DNLS1F': ('the land: founding: a litrpg saga',
#   'theland:founding:alitrpgsaga'),
#  'B01JKDTP26': ('small great things', 'smallgreatthings'),
#  'B01MTYYPKY': ('thrawn (star wars)', 'thrawn(starwars)'),
#  'B006R6YWEQ': ('american sniper', 'americansniper'),
#  'B003ILGSFE': ("the girl who kicked the hornet's nest",
#   "thegirlwhokickedthehornet'snest"),
#  'B005ZUI3OA': ('the alloy of law', 'thealloyoflaw'),
#  'B00DVQDX18': ("the husband's secret", "thehusband'ssecret"),
#  'B0061R8IP0': ('the fiery cross', 'thefierycross'),
#  'B07BHVWFSM': ('the singularity trap', 'thesingularitytrap'),
#  '1705015506': ('voyager: international edition, parts 1 and 2',
#   'voyager:internationaledition,parts1and2'),
#  'B007OXLE60': ('the witness', 'thewitness'),
#  'B00V6HEXGI': ('memory man', 'memoryman'),
#  'B072YT93QD': ('sufficiently advanced magic', 'sufficientlyadvancedmagic'),
#  'B002V8MMPU': ('grave peril', 'graveperil'),
#  'B002V00YSK': ('the book thief', 'thebookthief'),
#  'B07NDHNX8Z': ('the demon next door', 'thedemonnextdoor'),
#  'B002VA9TOU': ('dark places', 'darkplaces'),
#  'B01D0FJOAI': ('the adventures of tom stranger, interdimensional insurance agent',
#   'theadventuresoftomstranger,interdimensionalinsuranceagent'),
#  '0525639330': ('the guardians', 'theguardians'),
#  '1705014828': ('the fiery cross: international edition',
#   'thefierycross:internationaledition'),
#  'B007KSJKI8': ('theft of swords', 'theftofswords'),
#  'B084G9WVWZ': ('tell me lies', 'tellmelies'),
#  'B078SG5VPQ': ('the terminal list', 'theterminallist'),
#  'B00JDQ99IQ': ('skin game', 'skingame'),
#  'B07MBBHPQ5': ('the things we cannot say', 'thethingswecannotsay'),
#  'B07773BYJV': ('a higher loyalty', 'ahigherloyalty'),
#  'B002VA8GSA': ('kitchen confidential', 'kitchenconfidential'),
#  'B008EYO88O': ('shadow of night', 'shadowofnight'),
#  'B00EFB8RPA': ('sycamore row', 'sycamorerow'),
#  'B018RDY61A': ('end of watch', 'endofwatch'),
#  'B002V189R2': ('summer knight', 'summerknight'),
#  'B088C4DBYP': ("heaven's river", "heaven'sriver"),
#  'B007TLCUCO': ('fifty shades darker', 'fiftyshadesdarker'),
#  'B00BOU8PZC': ('orphan train', 'orphantrain'),
#  'B0191YTGI2': ('when breath becomes air', 'whenbreathbecomesair'),
#  'B07NP9L44Y': ('a mind of her own', 'amindofherown'),
#  'B002V5H6F4': ('animal farm', 'animalfarm'),
#  'B00U7T90L4': ('finders keepers', 'finderskeepers'),
#  '1250260604': ("american dirt (oprah's book club)",
#   "americandirt(oprah'sbookclub)"),
#  'B074G5S1DY': ('braving the wilderness', 'bravingthewilderness'),
#  'B005HIR9VI': ('the night circus', 'thenightcircus'),
#  'B07BZC9GLC': ('the tattooist of auschwitz', 'thetattooistofauschwitz'),
#  'B072VTTP23': ('the land: forging', 'theland:forging'),
#  'B002V9ZE4A': ('death masks: the dresden files',
#   'deathmasks:thedresdenfiles'),
#  'B003C24LIA': ('dead beat', 'deadbeat'),
#  'B00K8F6KQA': ('the book of life', 'thebookoflife'),
#  'B002V5D950': ('think and grow rich', 'thinkandgrowrich'),
#  'B07QD1ZW5X': ('even tree nymphs get the blues', 'eventreenymphsgettheblues'),
#  'B002V1O7UU': ('one second after', 'onesecondafter'),
#  'B011PVYB2A': ('a knight of the seven kingdoms', 'aknightofthesevenkingdoms'),
#  'B009Z485KY': ('cold days', 'colddays'),
#  'B002V5GN4Y': ('the secret', 'thesecret'),
#  'B074XHTN3W': ('year one', 'yearone'),
#  'B002UZML5K': ('the shadow rising', 'theshadowrising'),
#  'B01CUKULGA': ('dark matter', 'darkmatter'),
#  'B0078PA1OA': ('dracula [audible edition]', 'dracula[audibleedition]'),
#  '059334023X': ('the midnight library', 'themidnightlibrary'),
#  'B002V0M190': ('under the dome', 'underthedome'),
#  'B003C28QUE': ('blood rites', 'bloodrites'),
#  'B002VACELA': ('proven guilty: the dresden files',
#   'provenguilty:thedresdenfiles'),
#  'B00U0CAEB8': ('big magic', 'bigmagic'),
#  'B003DORDUU': ('changes: the dresden files2', 'changes:thedresdenfiles2'),
#  'B002V1BVK4': ('brave new world', 'bravenewworld'),
#  'B002V1O7D2': ("old man's war", "oldman'swar"),
#  'B07M79KY6L': ('lucky suit', 'luckysuit'),
#  'B07DJYBXNC': ('dare to lead', 'daretolead'),
#  'B002V1LFU0': ('an echo in the bone', 'anechointhebone'),
#  'B07YYMW9ZZ': ('the christmas pact', 'thechristmaspact'),
#  'B01N4DCBK6': ('homo deus', 'homodeus'),
#  'B077GG86LW': ('fire and fury', 'fireandfury'),
#  'B014LLCT7A': ('shadows of self', 'shadowsofself'),
#  'B00URXOQ1E': ('the art of war', 'theartofwar'),
#  'B002V0M1R2': ('turn coat', 'turncoat'),
#  'B00XV1ALO0': ('blood of elves', 'bloodofelves'),
#  'B002V00SWM': ('white night: the dresden files',
#   'whitenight:thedresdenfiles'),
#  'B007EZKMP2': ('the song of achilles', 'thesongofachilles'),
#  'B0163E2K22': ('year of yes', 'yearofyes'),
#  'B002V1L9VU': ('small favor', 'smallfavor'),
#  'B07F43574T': ('the coming storm', 'thecomingstorm'),
#  'B002UZZ25G': ('water for elephants', 'waterforelephants'),
#  'B07424XXN2': ('the land: alliances: a litrpg saga',
#   'theland:alliances:alitrpgsaga'),
#  'B00S8FDCTK': ('fear the sky', 'fearthesky'),
#  'B006PFYCW6': ('star wars: darth plagueis', 'starwars:darthplagueis'),
#  '1705015301': ('an echo in the bone: international edition',
#   'anechointhebone:internationaledition'),
#  'B002UZLEFS': ('alexander hamilton', 'alexanderhamilton'),
#  'B00I8NRAE0': ('10% happier', '10%happier'),
#  'B005IHAT1A': ('star wars: heir to the empire', 'starwars:heirtotheempire'),
#  '1984888471': ('city of girls', 'cityofgirls'),
#  'B019NNTLBS': ('the dark tower ii', 'thedarktowerii'),
#  'B00551W570': ('go the f--k to sleep', 'gothef--ktosleep'),
#  'B073H9PF2D': ('leviathan wakes', 'leviathanwakes'),
#  'B0081IIZ6Y': ('rise of empire', 'riseofempire'),
#  'B07F3MCHF4': ('the land: predators: a litrpg saga',
#   'theland:predators:alitrpgsaga'),
#  '1250759781': ('rhythm of war', 'rhythmofwar'),
#  'B006IE4OY0': ('the untethered soul', 'theuntetheredsoul'),
#  'B00IMLEZG4': ('the silkworm', 'thesilkworm'),
#  'B00JBKB7YI': ("written in my own heart's blood",
#   "writteninmyownheart'sblood"),
#  'B0797FYNDC': ('pet sematary', 'petsematary'),
#  'B012HQ7IPY': ('the fifth season', 'thefifthseason'),
#  'B07YVL6K4G': ('you can thank me later', 'youcanthankmelater'),
#  'B07D7JMB27': ('the reckoning', 'thereckoning'),
#  'B01LY6GN0F': ('reign of madness', 'reignofmadness'),
#  'B07NNSQ4YD': ('the deep, deep snow', 'thedeep,deepsnow'),
#  'B007UR5AAG': ('fifty shades freed', 'fiftyshadesfreed'),
#  'B0742MJ2YL': ("we're going to need more wine", "we'regoingtoneedmorewine"),
#  'B082LSC2RR': ('junkyard cats', 'junkyardcats'),
#  'B00DC8GDVC': ('the richest man in babylon', 'therichestmaninbabylon'),
#  'B074V9MCRJ': ('the land: catacombs', 'theland:catacombs'),
#  'B002V0A7U0': ('the tipping point', 'thetippingpoint'),
#  'B00M27LBU2': ('zero to one', 'zerotoone'),
#  'B00S5HOIL2': ('an unwelcome quest', 'anunwelcomequest'),
#  'B0189QQXRA': ('the bands of mourning', 'thebandsofmourning'),
#  'B00K7PP15W': ('cibola burn', 'cibolaburn'),
#  'B00BWYDMK8': ('the great gatsby', 'thegreatgatsby'),
#  'B01CUK4LUC': ('lilac girls', 'lilacgirls'),
#  'B003O9GBFC': ('the passage', 'thepassage'),
#  'B01187MRAE': ('the lake house', 'thelakehouse'),
#  'B00KHEK842': ('spell or high water', 'spellorhighwater'),
#  'B002VA3PBI': ('the dark tower: the dark tower vii',
#   'thedarktower:thedarktowervii'),
#  'B002UZJIF6': ('the magicians', 'themagicians'),
#  'B002V8N9VG': ('speaker for the dead', 'speakerforthedead'),
#  'B019NNT1G8': ('the dark tower iii', 'thedarktoweriii'),
#  'B01K3EKD8Q': ('the wrong side of goodbye', 'thewrongsideofgoodbye'),
#  'B074NBPW86': ('the last mrs. parrish', 'thelastmrs.parrish'),
#  'B078NZ6PFP': ('the land: raiders: a litrpg saga',
#   'theland:raiders:alitrpgsaga'),
#  'B07FSY3DBG': ('girl, stop apologizing (audible exclusive edition)',
#   'girl,stopapologizing(audibleexclusiveedition)'),
#  'B002V8LI0U': ('anansi boys', 'anansiboys'),
#  'B01ATTSTCM': ('the last mile', 'thelastmile'),
#  '1984845306': ('daisy jones & the six', 'daisyjones&thesix'),
#  'B00Y1O1FYG': ('nemesis games', 'nemesisgames'),
#  'B07RHW7Z6Q': ('the dead drink first', 'thedeaddrinkfirst'),
#  'B00S5AAHLY': ('the shadow of what was lost', 'theshadowofwhatwaslost'),
#  'B004RGQ6UQ': ('monster hunter international', 'monsterhunterinternational'),
#  'B086R2N27Y': ('how to defeat a demon king in ten easy steps',
#   'howtodefeatademonkinginteneasysteps'),
#  'B00BIKAVHS': ('world war z: the complete edition',
#   'worldwarz:thecompleteedition'),
#  'B002V1NG16': ('the golden compass: his dark materials',
#   'thegoldencompass:hisdarkmaterials'),
#  'B006LPK3WS': ('a wrinkle in time', 'awrinkleintime'),
#  'B002UZN0PA': ('the gathering storm', 'thegatheringstorm'),
#  '0062985051': ('the guest list', 'theguestlist'),
#  'B007KSRURG': ('the innocent: a novel', 'theinnocent:anovel'),
#  'B071FBNW5T': ('stillhouse lake', 'stillhouselake'),
#  'B0031AS3BE': ('the 4-hour workweek (expanded and updated)',
#   'the4-hourworkweek(expandedandupdated)'),
#  'B07KYVZFT7': ('the testaments', 'thetestaments'),
#  'B008PEX62M': ("salem's lot", "salem'slot"),
#  'B002V1LTME': ('world without end', 'worldwithoutend'),
#  'B002V1AGNC': ('the lost symbol', 'thelostsymbol'),
#  'B076PPCJRM': ('the land: swarm', 'theland:swarm'),
#  'B003UNYZ7I': ('the gray man', 'thegrayman'),
#  'B0042ZEIDO': ('fall of giants', 'fallofgiants'),
#  'B01M0YKIZA': ('star wars: ahsoka', 'starwars:ahsoka'),
#  'B01N9EC5T7': ('you are a badass at making money',
#   'youareabadassatmakingmoney'),
#  'B07QTC89BM': ('more bedtime stories for cynics',
#   'morebedtimestoriesforcynics'),
#  'B0044UOB2K': ('american assassin', 'americanassassin'),
#  'B00M27LYVS': ('leaving time', 'leavingtime'),
#  'B002V0QK4C': ("wizard's first rule", "wizard'sfirstrule"),
#  '1338635204': ('the ballad of songbirds and snakes',
#   'theballadofsongbirdsandsnakes'),
#  '125031724X': ('the four winds', 'thefourwinds'),
#  'B00P0277C2': ('the three-body problem', 'thethree-bodyproblem'),
#  '1781103798': ('the tales of beedle the bard', 'thetalesofbeedlethebard'),
#  'B06WWHJWYJ': ('black privilege', 'blackprivilege'),
#  'B002UUKWCY': ('snow crash', 'snowcrash'),
#  'B07HL32CTW': ('when you find me', 'whenyoufindme'),
#  'B019NNX0G0': ('the dark tower iv', 'thedarktoweriv'),
#  'B00UVR0LWY': ('ghost story', 'ghoststory'),
#  'B01DFBXDN6': ('the magnolia story', 'themagnoliastory'),
#  'B07T1F4MB7': ('the man who knew the way to the moon',
#   'themanwhoknewthewaytothemoon'),
#  'B01N0BGPO9': ('behind her eyes', 'behindhereyes'),
#  'B004Y0IWL6': ('a breath of snow and ashes', 'abreathofsnowandashes'),
#  '0525637141': ('the vanishing half', 'thevanishinghalf'),
#  'B06ZXWKQCQ': ('i found you', 'ifoundyou'),
#  'B01N5US9UJ': ('hell divers ii: ghosts', 'helldiversii:ghosts'),
#  '1549170848': ('catch and kill', 'catchandkill'),
#  'B00375PP4Q': ('genghis khan and the making of the modern world',
#   'genghiskhanandthemakingofthemodernworld'),
#  'B014JYRHNA': ('the crossing', 'thecrossing'),
#  'B00WRHY15Y': ('a court of thorns and roses', 'acourtofthornsandroses'),
#  'B076HY6P86': ('the president is missing', 'thepresidentismissing'),
#  'B07BKP4BF6': ('the fallen', 'thefallen'),
#  'B01IIABNIG': ('the couple next door', 'thecouplenextdoor'),
#  '177424361X': ('critical mass', 'criticalmass'),
#  'B002V59YC2': ('the lincoln lawyer', 'thelincolnlawyer'),
#  'B06Y1RH224': ('american kingpin', 'americankingpin'),
#  'B082YHVMCG': ('cut and run', 'cutandrun'),
#  '1549134663': ('midnight sun', 'midnightsun'),
#  '0593290704': ('peace talks', 'peacetalks'),
#  '059321000X': ('pretty things', 'prettythings'),
#  'B00BU8KV2S': ('the golem and the jinni', 'thegolemandthejinni'),
#  'B00W8DAB9M': ('the cycle of arawn', 'thecycleofarawn'),
#  'B002V0PTQ2': ('the road', 'theroad'),
#  'B002V8H660': ('dune messiah', 'dunemessiah'),
#  'B07WWYW1JT': ('carnival row: tangle in the dark',
#   'carnivalrow:tangleinthedark'),
#  'B07B1J873J': ('how to change your mind', 'howtochangeyourmind'),
#  'B002V8KTYG': ('born to run: a hidden tribe, superathletes, and the greatest race the world has never seen',
#   'borntorun:ahiddentribe,superathletes,andthegreatestracetheworldhasneverseen'),
#  'B00K252ET8': ('the obstacle is the way', 'theobstacleistheway'),
#  '1705014836': ('a breath of snow and ashes: international edition',
#   'abreathofsnowandashes:internationaledition'),
#  'B00FPMTFRM': ('the one thing', 'theonething'),
#  'B00VSEM9QK': ('rising strong', 'risingstrong'),
#  'B06VW6BQHF': ('camino island', 'caminoisland'),
#  'B017WP4D6C': ('sword of destiny', 'swordofdestiny'),
#  'B07BC2VDH3': ('the ruin', 'theruin'),
#  'B01JKG9E9M': ('the whistler', 'thewhistler'),
#  'B005TKKCWC': ('thinking, fast and slow', 'thinking,fastandslow'),
#  'B07FK3M9QZ': ('wishes and wellingtons', 'wishesandwellingtons'),
#  'B00WYDJ2YQ': ('48 laws of power', '48lawsofpower'),
#  'B00CX723U8': ('red sparrow', 'redsparrow'),
#  'B07LFLM4LJ': ('take control of your life', 'takecontrolofyourlife'),
#  'B002V57S6G': ('the forgotten garden', 'theforgottengarden'),
#  'B00O4FH8E8': ('just mercy (movie tie-in edition)',
#   'justmercy(movietie-inedition)'),
#  'B07XTQWKXK': ('the burnout generation', 'theburnoutgeneration'),
#  'B01D53NPLO': ("babylon's ashes", "babylon'sashes"),
#  'B079LRSMNN': ("galaxy's edge", "galaxy'sedge"),
#  'B014JYRSPW': ('career of evil', 'careerofevil'),
#  'B08645RLZP': ('second skin', 'secondskin'),
#  'B072YT17GJ': ('trouble on paradise', 'troubleonparadise'),
#  'B0143O99FK': ("the aeronaut's windlass", "theaeronaut'swindlass"),
#  'B002V0RAUU': ('a new earth', 'anewearth'),
#  'B005V2HRA8': ('is everyone hanging out without me? (and other concerns)',
#   'iseveryonehangingoutwithoutme?(andotherconcerns)'),
#  'B077Y7PLS4': ('thrawn: alliances (star wars)', 'thrawn:alliances(starwars)'),
#  'B002UZKJSG': ('the millionaire next door', 'themillionairenextdoor'),
#  'B07H4XVBBW': ('power moves', 'powermoves'),
#  'B014LL6R5U': ('the blade itself', 'thebladeitself'),
#  'B002VA9X9Q': ('in the woods', 'inthewoods'),
#  'B017WRZO9U': ('smarter faster better', 'smarterfasterbetter'),
#  'B074WH171J': ('paradox bound', 'paradoxbound'),
#  '1250314208': ('an anonymous girl', 'ananonymousgirl'),
#  'B079P67584': ('shelter in place', 'shelterinplace'),
#  'B00KYUYM14': ('lock in (narrated by wil wheaton)',
#   'lockin(narratedbywilwheaton)'),
#  'B0746RFM3R': ('the rooster bar', 'theroosterbar'),
#  'B07MR6RY3T': ('the conception of terror: tales inspired by m. r. james - volume 1',
#   'theconceptionofterror:talesinspiredbym.r.james-volume1'),
#  'B002UZL9G2': ('atlas shrugged', 'atlasshrugged'),
#  'B075DK95GS': ("caliban's war", "caliban'swar"),
#  'B06ZZPN9LH': ('al franken, giant of the senate',
#   'alfranken,giantofthesenate'),
#  '0593343050': ('battle ground', 'battleground'),
#  '1250222281': ('stay sexy & don’t get murdered', 'staysexy&don’tgetmurdered'),
#  'B00TAC05GI': ('go set a watchman', 'gosetawatchman'),
#  'B0045V31HY': ('patient zero', 'patientzero'),
#  'B01B8IGYGQ': ('back blast', 'backblast'),
#  'B00DZ0G088': ('the crown tower', 'thecrowntower'),
#  'B07DX9W2CG': ('daring greatly', 'daringgreatly'),
#  'B072359S7K': ('the seven husbands of evelyn hugo',
#   'thesevenhusbandsofevelynhugo'),
#  'B002V1OC5A': ('duma key', 'dumakey'),
#  'B01N6XS0HX': ('the operator', 'theoperator'),
#  'B002V8OCCQ': ('the maze runner', 'themazerunner'),
#  'B002V1LT0G': ('the cold dish: a walt longmire mystery',
#   'thecolddish:awaltlongmiremystery'),
#  'B00DLI07C4': ('blood song', 'bloodsong'),
#  'B002V1NHJ2': ('the lion, the witch, and the wardrobe',
#   'thelion,thewitch,andthewardrobe'),
#  'B01D24NLWO': ('algorithms to live by', 'algorithmstoliveby'),
#  'B07K4VYQ5X': ('zero g', 'zerog'),
#  'B0071NK7KM': ('kill shot', 'killshot'),
#  'B002V1OHGE': ('awaken the giant within', 'awakenthegiantwithin'),
#  'B00ENI4SS0': ('and then there were none', 'andthentherewerenone'),
#  'B01N12D4UJ': ('the fix', 'thefix'),
#  'B01J6CZQGA': ('the underground railroad (television tie-in)',
#   'theundergroundrailroad(televisiontie-in)'),
#  'B00RDB35II': ('red queen', 'redqueen'),
#  'B002UZLH4Q': ('firefly lane', 'fireflylane'),
#  'B015RQON6I': ('killing floor', 'killingfloor'),
#  'B00875DTH6': ('star wars: dark force rising: the thrawn trilogy',
#   'starwars:darkforcerising:thethrawntrilogy'),
#  'B00FJJFO1C': ('the everything store', 'theeverythingstore'),
#  '0062973428': ('inside out', 'insideout'),
#  'B0043WI3N2': ('the glass castle', 'theglasscastle'),
#  'B00B3YURD2': ('lean in', 'leanin'),
#  'B00893WAG2': ('star wars: the thrawn trilogy: the last command',
#   'starwars:thethrawntrilogy:thelastcommand'),
#  'B002UZMXPI': ('angels and demons', 'angelsanddemons'),
#  'B07BFHRVGB': ('last week tonight with john oliver presents a day in the life of marlon bundo',
#   'lastweektonightwithjohnoliverpresentsadayinthelifeofmarlonbundo'),
#  'B00ZH2YLPG': ("my grandmother asked me to tell you she's sorry",
#   "mygrandmotheraskedmetotellyoushe'ssorry"),
#  '125077795X': ('the invisible life of addie larue',
#   'theinvisiblelifeofaddielarue'),
#  'B003UDDK7O': ('good to great', 'goodtogreat'),
#  'B002UUMS76': ('wolves of the calla: dark tower v',
#   'wolvesofthecalla:darktowerv'),
#  'B009PSMXXU': ('path of destruction', 'pathofdestruction'),
#  'B07MDDG8PZ': ('on the shoulders of titans', 'ontheshouldersoftitans'),
#  'B01G49TI62': ('the woman in cabin 10', 'thewomanincabin10'),
#  'B01092KDCS': ('the time of contempt', 'thetimeofcontempt'),
#  'B002V9ZA1M': ('breaking dawn', 'breakingdawn'),
#  'B071DJZ1KZ': ('come sundown', 'comesundown'),
#  'B08C3XGN8L': ("the cuckoo's cry", "thecuckoo'scry"),
#  '1538522039': ('the book woman of troublesome creek',
#   'thebookwomanoftroublesomecreek'),
#  'B0161R0XBQ': ('age of myth', 'ageofmyth'),
#  'B004DR2CNE': ('agent to the stars', 'agenttothestars'),
#  'B01DYO4QRQ': ('a court of mist and fury', 'acourtofmistandfury'),
#  'B0036KBSXY': ('winter garden', 'wintergarden'),
#  'B003D8W5VS': ('foundation (apple series tie-in edition)',
#   'foundation(appleseriestie-inedition)'),
#  'B00UK4A1NC': ('the liar', 'theliar'),
#  'B078892NLF': ('how to date your dragon', 'howtodateyourdragon'),
#  'B01KIOP1QA': ('free the darkness', 'freethedarkness'),
#  'B07BN2GNQQ': ('the dichotomy of leadership', 'thedichotomyofleadership'),
#  'B00CLCNROG': ('the miracle morning', 'themiraclemorning'),
#  'B00B4EHL6C': ('the storyteller', 'thestoryteller'),
#  'B009PNTJE6': ('the secret keeper', 'thesecretkeeper'),
#  'B01K5Q6VWO': ('arcanum unbounded: the cosmere collection',
#   'arcanumunbounded:thecosmerecollection'),
#  'B0728KGR56': ('two kinds of truth', 'twokindsoftruth'),
#  'B00DEL0ERQ': ('the rosie project', 'therosieproject'),
#  '1980006520': ("tiamat's wrath", "tiamat'swrath"),
#  'B074XM52YQ': ('persepolis rising', 'persepolisrising'),
#  '0593168550': ('a time for mercy', 'atimeformercy'),
#  'B06WLMWF2S': ('sherlock holmes', 'sherlockholmes'),
#  '1478999284': ('long road to mercy', 'longroadtomercy'),
#  'B00IRI3JIW': ('the hospital: the first mountain man story',
#   'thehospital:thefirstmountainmanstory'),
#  'B002V1O6X8': ('altered carbon', 'alteredcarbon'),
#  'B002V8HC7I': ('furies of calderon: codex alera',
#   'furiesofcalderon:codexalera'),
#  'B07MFWKPJ7': ('heads will roll', 'headswillroll'),
#  'B077NGB78R': ('legends of ahn', 'legendsofahn'),
#  'B002V1NT6I': ('new moon', 'newmoon'),
#  'B002UZN6SQ': ('the poet', 'thepoet'),
#  'B00HUZO3CE': ('free: the jester (a riyria chronicles tale)',
#   'free:thejester(ariyriachroniclestale)'),
#  'B002V8HAO8': ('starship troopers', 'starshiptroopers'),
#  'B08BDQ36W5': ('agent 355', 'agent355'),
#  'B002V08E64': ('the five dysfunctions of a team',
#   'thefivedysfunctionsofateam'),
#  '1797105833': ('anxious people', 'anxiouspeople'),
#  'B005Y2AHHU': ('zero day', 'zeroday'),
#  'B07DF4BTXN': ('nine perfect strangers', 'nineperfectstrangers'),
#  'B073PG4DX8': ('ascend online', 'ascendonline'),
#  'B014JWSCWW': ('see me', 'seeme'),
#  'B00JTZP29G': ('sell or be sold: how to get your way in business and in life',
#   'sellorbesold:howtogetyourwayinbusinessandinlife'),
#  'B013XNVR3E': ('after you', 'afteryou'),
#  'B07MT4MTGP': ('the mystwick school of musicraft',
#   'themystwickschoolofmusicraft'),
#  'B01N6DLACM': ('gunmetal gray', 'gunmetalgray'),
#  'B074B2G3LQ': ('silent child', 'silentchild'),
#  'B011PVXPO0': ('aftermath: star wars', 'aftermath:starwars'),
#  'B07L17XRPV': ('atomic marriage', 'atomicmarriage'),
#  'B06X16L1XR': ('age of swords', 'ageofswords'),
#  '0593339800': ("caste (oprah's book club)", "caste(oprah'sbookclub)"),
#  'B01EM6QN30': ('the butterfly garden', 'thebutterflygarden'),
#  'B074GG7MT1': ('andrea vernon and the corporation for ultrahuman protection',
#   'andreavernonandthecorporationforultrahumanprotection'),
#  'B004XMIMHE': ('hard magic', 'hardmagic'),
#  'B01KGL13FI': ('anne of green gables', 'anneofgreengables'),
#  'B0147QLE98': ('a little life', 'alittlelife'),
#  'B0099D5TA0': ('winter of the world', 'winteroftheworld'),
#  'B00F5BVQQQ': ('the rose and the thorn', 'theroseandthethorn'),
#  'B002V5A0BG': ('eat, pray, love', 'eat,pray,love'),
#  'B003VWJAPA': ('the rise and fall of the third reich',
#   'theriseandfallofthethirdreich'),
#  'B00OPAR4MI': ('money: master the game', 'money:masterthegame'),
#  'B01GEWX4QY': ('the last tribe', 'thelasttribe'),
#  '1531834515': ('of blood and bone', 'ofbloodandbone'),
#  'B06W5S4WHT': ('the black book', 'theblackbook'),
#  'B0783R9DPV': ('crushing it!', 'crushingit!'),
#  '1549119842': ('lethal white', 'lethalwhite'),
#  '1982648066': ('the compound effect', 'thecompoundeffect'),
#  'B07Z6MV4TD': ('tinaca jones', 'tinacajones'),
#  'B004708FYW': ('side jobs', 'sidejobs'),
#  'B002V5CO3I': ('song of susannah: the dark tower vi',
#   'songofsusannah:thedarktowervi'),
#  '1774246325': ('brushfire', 'brushfire'),
#  'B014LL69TO': ('before they are hanged', 'beforetheyarehanged'),
#  'B00J5490FI': ('the target', 'thetarget'),
#  'B01N5P9MG0': ('into the water', 'intothewater'),
#  'B01NAEEJJV': ('killers of the flower moon', 'killersoftheflowermoon'),
#  'B003VW6KU8': ('her royal spyness', 'herroyalspyness'),
#  'B004RGOQM6': ('monster hunter vendetta', 'monsterhuntervendetta'),
#  '148820697X': ('the wives', 'thewives'),
#  'B002UZKVI4': ('the talisman', 'thetalisman'),
#  'B078MSDQVS': ("the liar's girl", "theliar'sgirl"),
#  '1984889966': ('thrawn: treason', 'thrawn:treason'),
#  'B012DWJ4N6': ('baptism of fire', 'baptismoffire'),
#  'B00L89P0C0': ('mean streak', 'meanstreak'),
#  'B01L0H7I24': ('talking as fast as i can', 'talkingasfastasican'),
#  'B07HY7TSLY': ('true believer', 'truebeliever'),
#  'B0036KZN9E': ('eclipse: the twilight saga', 'eclipse:thetwilightsaga'),
#  'B005LXV0HI': ('the lean startup', 'theleanstartup'),
#  'B00J7R07Z0': ('the collector', 'thecollector'),
#  'B002V1A0WE': ('on writing', 'onwriting'),
#  'B00YCDLRDK': ('free: professional integrity (a riyria chronicles tale)',
#   'free:professionalintegrity(ariyriachroniclestale)'),
#  'B003B2ZV8K': ('the big short', 'thebigshort'),
#  'B01H43LCPW': ('be obsessed or be average', 'beobsessedorbeaverage'),
#  'B0176MUUGS': ('living with a seal', 'livingwithaseal'),
#  'B002UZHP1U': ('the subtle knife: his dark materials',
#   'thesubtleknife:hisdarkmaterials'),
#  'B00R8JJE12': ('dead wake', 'deadwake'),
#  'B004YLIJ04': ('transfer of power', 'transferofpower'),
#  'B00I0AJC2Y': ('the hard thing about hard things',
#   'thehardthingabouthardthings'),
#  'B01A9E8GJI': ('fear the future', 'fearthefuture'),
#  'B00CP5CC9U': ('hunted: the iron druid chronicles',
#   'hunted:theirondruidchronicles'),
#  'B01DDUHR6S': ('before the fall', 'beforethefall'),
#  'B0189PX1RQ': ('deep work', 'deepwork'),
#  'B071H4FK2Y': ('call me by your name', 'callmebyyourname'),
#  'B00NLEVIRG': ('as you wish', 'asyouwish'),
#  'B071GS25H4': ('what happened', 'whathappened'),
#  '0525499334': ('the ride of a lifetime', 'therideofalifetime'),
#  'B009P8K404': ("rich dad's cashflow quadrant", "richdad'scashflowquadrant"),
#  'B002V1CD0G': ('gone with the wind', 'gonewiththewind'),
#  'B01FEAXNKO': ('super powereds: year 1', 'superpowereds:year1'),
#  'B06Y5ZWKPR': ('the late show', 'thelateshow'),
#  'B0043BUG3I': ('on target', 'ontarget'),
#  'B002V5GNJ4': ('moon called', 'mooncalled'),
#  'B002UZL1CY': ("ender's shadow", "ender'sshadow"),
#  'B008DJ074E': ('bared to you', 'baredtoyou'),
#  'B002V1LGZE': ('the e-myth revisited', 'thee-mythrevisited'),
#  'B07QR7FJFP': ('black crow, white snow', 'blackcrow,whitesnow'),
#  'B01KBM825G': ('the undoing project', 'theundoingproject'),
#  'B074MJDNFC': ('an echo of things to come', 'anechoofthingstocome'),
#  'B08FCW35B1': ('murder by other means', 'murderbyothermeans'),
#  '1797104802': ('if it bleeds', 'ifitbleeds'),
#  'B00VAZZY32': ('the phoenix project', 'thephoenixproject'),
#  'B01HZXFARW': ('the black prism', 'theblackprism'),
#  'B079YYJK47': ('galaxy outlaws: the complete black ocean mobius missions, 1-16.5',
#   'galaxyoutlaws:thecompleteblackoceanmobiusmissions,1-16.5'),
#  'B002V0RK78': ('a thousand splendid suns', 'athousandsplendidsuns'),
#  'B002UZZDI2': ("the titan's curse", "thetitan'scurse"),
#  'B01K5RQ6J6': ('the obelisk gate', 'theobeliskgate'),
#  'B011PVXK90': ('rogue lawyer', 'roguelawyer'),
#  'B0089ETR9Y': ("the hypnotist's love story", "thehypnotist'slovestory"),
#  'B00884I4XA': ('beautiful ruins', 'beautifulruins'),
#  'B005EGKBYK': ('monster hunter alpha', 'monsterhunteralpha'),
#  'B071P2Y8PQ': ('sleeping beauties', 'sleepingbeauties'),
#  'B00XWTN7PQ': ('in a dark, dark wood', 'inadark,darkwood'),
#  'B01N4NYAWT': ('a column of fire', 'acolumnoffire'),
#  'B0036JVO6G': ('the da vinci code', 'thedavincicode'),
#  'B002V0QR4K': ('a dirty job', 'adirtyjob'),
#  'B002UZDT2E': ('odd thomas', 'oddthomas'),
#  'B00MQ2UICK': ('the escape', 'theescape'),
#  'B019WKOU18': ('find her', 'findher'),
#  'B006YD7YZ6': ('defending jacob', 'defendingjacob'),
#  'B009PRF7RU': ('if you find me', 'ifyoufindme'),
#  'B01GSIZCEG': ('all the ugly and wonderful things',
#   'alltheuglyandwonderfulthings'),
#  'B07KX52L88': ("the queen's gambit", "thequeen'sgambit"),
#  'B0752ZQR33': ('why we sleep', 'whywesleep'),
#  '1549151967': ('one good deed', 'onegooddeed'),
#  'B002V1CO82': ('the lost world', 'thelostworld'),
#  'B01KGJVBIO': ('two by two', 'twobytwo'),
#  '0525494855': ('the water dancer (oprah’s book club)',
#   'thewaterdancer(oprah’sbookclub)'),
#  'B07CL3F5H2': ('fire & blood (hbo tie-in edition)',
#   'fire&blood(hbotie-inedition)'),
#  '0593164407': ('thank you for my service', 'thankyouformyservice'),
#  'B00VAW2XZC': ('furiously happy', 'furiouslyhappy'),
#  'B00NPB6OBU': ('being mortal', 'beingmortal'),
#  'B01EIA86VC': ('how to be a 3% man', 'howtobea3%man'),
#  'B01K8S3XDE': ('the blood mirror', 'thebloodmirror'),
#  'B014JWR5I4': ('the guilty', 'theguilty'),
#  'B002V9ZFSK': ('the ghost brigades', 'theghostbrigades'),
#  'B002V0KCTQ': ('consent to kill', 'consenttokill'),
#  'B00IPK3BWQ': ('creativity, inc.', 'creativity,inc.'),
#  'B002V0GCE0': ('predictably irrational', 'predictablyirrational'),
#  'B00NP9WS58': ('the silent sister', 'thesilentsister'),
#  'B01N4DBURT': ('this is how it always is', 'thisishowitalwaysis'),
#  '1538553414': ('hell divers iv: wolves', 'helldiversiv:wolves'),
#  'B00J27VX9Y': ('the first fifteen lives of harry august',
#   'thefirstfifteenlivesofharryaugust'),
#  'B00T3OCE1W': ('red notice', 'rednotice'),
#  'B003AO3P5A': ("the farseer: assassin's apprentice",
#   "thefarseer:assassin'sapprentice"),
#  'B07L5WYT38': ('the christmas hirelings', 'thechristmashirelings'),
#  'B00G5HFAQG': ('the gods of guilt', 'thegodsofguilt'),
#  'B07DHS7PP5': ('21 lessons for the 21st century',
#   '21lessonsforthe21stcentury'),
#  'B005F0O484': ('the magician king', 'themagicianking'),
#  'B00MMHE384': ('13 hours', '13hours'),
#  'B06Y13NFQ7': ('fight and flight', 'fightandflight'),
#  '1508284121': ('the turn of the key', 'theturnofthekey'),
#  'B082BHJMFF': ('the martian', 'themartian'),
#  'B00JS9K7OI': ('still life', 'stilllife'),
#  'B074XK2R2X': ('second hand curses', 'secondhandcurses'),
#  'B07DK1BBS6': ('past tense', 'pasttense'),
#  'B016CNA49A': ('how not to die', 'hownottodie'),
#  'B00BWX30JM': ('the hit', 'thehit'),
#  'B005ZT0X1C': ('star wars: the old republic: revan',
#   'starwars:theoldrepublic:revan'),
#  'B01N4S7VVP': ('fantastic beasts and where to find them',
#   'fantasticbeastsandwheretofindthem'),
#  'B002UZJJHI': ('the poisonwood bible', 'thepoisonwoodbible'),
#  'B00ENJ4J1K': ('murder on the orient express', 'murderontheorientexpress'),
#  'B072BFQF1N': ('a court of wings and ruin', 'acourtofwingsandruin'),
#  'B076VW7L7C': ('knights magi', 'knightsmagi'),
#  '1508299625': ('savage son', 'savageson'),
#  'B06W583DDK': ('the tea girl of hummingbird lane',
#   'theteagirlofhummingbirdlane'),
#  'B01CRMO9BE': ('star wars: bloodline - new republic',
#   'starwars:bloodline-newrepublic'),
#  'B00FW2B3H0': ('dead eye', 'deadeye'),
#  'B00LV6V4UW': ('what if?', 'whatif?'),
#  'B00309SYV0': ('freedom (tm)', 'freedom(tm)'),
#  'B00RKRDOM2': ('the like switch', 'thelikeswitch'),
#  'B002VAEK76': ('the black ice', 'theblackice'),
#  '1772307505': ('kingdoms and chaos', 'kingdomsandchaos'),
#  'B004AY444A': ('dead or alive', 'deadoralive'),
#  'B002V0QKG0': ('the way of shadows', 'thewayofshadows'),
#  'B002V5BHM2': ("the time traveler's wife", "thetimetraveler'swife"),
#  '0062953834': ('hustle harder, hustle smarter', 'hustleharder,hustlesmarter'),
#  'B00GBC0GB4': ('steel world', 'steelworld'),
#  'B002V5D5ZE': ('the restaurant at the end of the universe',
#   'therestaurantattheendoftheuniverse'),
#  'B01J6GNS9I': ('catalyst (star wars)', 'catalyst(starwars)'),
#  '1250622689': ('permanent record', 'permanentrecord'),
#  'B00DP6VRAI': ('the shack', 'theshack'),
#  '0593107063': ('such a fun age', 'suchafunage'),
#  'B0032G7016': ('crush it!', 'crushit!'),
#  'B002V18EH2': ("academ's fury: codex alera", "academ'sfury:codexalera"),
#  'B0813VYQYY': ('the minuteman', 'theminuteman'),
#  'B01GF36CIO': ('truly madly guilty', 'trulymadlyguilty'),
#  'B009H8KSA8': ('the twelve', 'thetwelve'),
#  'B00MOXI512': ('the slow regard of silent things',
#   'theslowregardofsilentthings'),
#  'B078HHFB23': ('agent in place', 'agentinplace'),
#  'B002V5D34W': ('the fall of hyperion', 'thefallofhyperion'),
#  'B004U5XPH6': ('stories i only tell my friends', 'storiesionlytellmyfriends'),
#  'B00M7RLNH8': ('edge of eternity', 'edgeofeternity'),
#  'B073BJD2F5': ('super sales on super heroes', 'supersalesonsuperheroes'),
#  'B002V5IY14': ('the testament', 'thetestament'),
#  'B007ZEAI3I': ('the end of the affair', 'theendoftheaffair'),
#  'B00JPK6A64': ('mere christianity', 'merechristianity'),
#  'B0036NEBJO': ('the warded man', 'thewardedman'),
#  'B01IQ15URC': ('the book of joy', 'thebookofjoy'),
#  'B002VAEON6': ('trunk music', 'trunkmusic'),
#  'B002V0PS5E': ('the host', 'thehost'),
#  'B00A9W1U58': ('threat vector', 'threatvector'),
#  'B002V0QPH4': ('me talk pretty one day', 'metalkprettyoneday'),
#  'B01KIQVHL6': ('empire of storms', 'empireofstorms'),
#  'B009PSL9I0': ('rule of two', 'ruleoftwo'),
#  'B00M9KCT12': ('waking up', 'wakingup'),
#  'B00K8F87C0': ("the magician's land", "themagician'sland"),
#  'B01GSIZ5AC': ('ego is the enemy', 'egoistheenemy'),
#  'B009HUF37O': ("mr. penumbra's 24-hour bookstore",
#   "mr.penumbra's24-hourbookstore"),
#  'B00MFSA7XU': ('yellow crocus', 'yellowcrocus'),
#  'B01D3AQT26': ('britt-marie was here', 'britt-mariewashere'),
#  'B008O8964Q': ('the righteous mind', 'therighteousmind'),
#  'B002V0TG16': ("cursor's fury: codex alera", "cursor'sfury:codexalera"),
#  'B01NCP56QD': ('the nowhere man', 'thenowhereman'),
#  'B00BP9FBU4': ('ordinary grace', 'ordinarygrace'),
#  'B002V8L8KU': ('the battle of the labyrinth', 'thebattleofthelabyrinth'),
#  'B002V0QF9M': ('into thin air', 'intothinair'),
#  'B077K4XXKV': ('a murder of manatees', 'amurderofmanatees'),
#  'B00354ZTDG': ('american gods [tv tie-in]', 'americangods[tvtie-in]'),
#  'B002V8DH5Y': ('stone of tears', 'stoneoftears'),
#  'B01I5OS9MI': ('super powereds: year 2', 'superpowereds:year2'),
#  'B074F9NBDR': ('age of war', 'ageofwar'),
#  'B01JKE3C24': ('night school', 'nightschool'),
#  'B01F65TBP8': ('the silver thief', 'thesilverthief'),
#  'B004T3KA0O': ('the fifth witness', 'thefifthwitness'),
#  '0062905007': ('open book', 'openbook'),
#  '1549142321': ('dark sacred night', 'darksacrednight'),
#  'B00M27L7TC': ('station eleven (television tie-in)',
#   'stationeleven(televisiontie-in)'),
#  'B07B3WPXMJ': ('brief cases', 'briefcases'),
#  'B00UVX4BPQ': ('a place called freedom', 'aplacecalledfreedom'),
#  'B009PPNDWS': ('the last man', 'thelastman'),
#  '1549142194': ("abaddon's gate", "abaddon'sgate"),
#  'B07FN214N8': ('every breath', 'everybreath'),
#  'B01FCY3W12': ('order to kill', 'ordertokill'),
#  'B00VQO3GPU': ('lords of the sith: star wars', 'lordsofthesith:starwars'),
#  'B00442FHU8': ('the scorch trials', 'thescorchtrials'),
#  'B06Y5R9X2S': ('magpie murders', 'magpiemurders'),
#  'B004VMD7BW': ('the grapes of wrath', 'thegrapesofwrath'),
#  'B06ZZ22PP1': ('the girl who was taken', 'thegirlwhowastaken'),
#  'B00L4IRLG8': ('tower lord', 'towerlord'),
#  'B01L7UC1SU': ('awaken online: catharsis', 'awakenonline:catharsis'),
#  'B01FY3KMKK': ('trump: the art of the deal', 'trump:theartofthedeal'),
#  'B00ZSUARF0': ('the mountain man omnibus', 'themountainmanomnibus'),
#  'B07288JYYG': ('the stone sky', 'thestonesky'),
#  'B083MSZTB7': ('alone with the stars', 'alonewiththestars'),
#  'B0091ZGFVI': ('monster hunter legion', 'monsterhunterlegion'),
#  'B07HNMVMK8': ('the consuming fire', 'theconsumingfire'),
#  'B00WXJHXQK': ('the survivor', 'thesurvivor'),
#  'B0764H7Y83': ('dungeon madness', 'dungeonmadness'),
#  'B005GFQ5WQ': ('the count of monte cristo', 'thecountofmontecristo'),
#  'B0096GJ7G2': ('the blinding knife', 'theblindingknife'),
#  '1524774367': ('blue moon', 'bluemoon'),
#  'B005OCRVZ6': ('killing lincoln', 'killinglincoln'),
#  'B004KAPD4Y': ('patriot games', 'patriotgames'),
#  '1982560487': ('hell divers v: captives', 'helldiversv:captives'),
#  'B076XSGP65': ('all systems red', 'allsystemsred'),
#  'B002V57VRC': ('children of dune', 'childrenofdune'),
#  'B003EYRWCS': ('halfway to the grave', 'halfwaytothegrave'),
#  'B071VTQZYT': ('leonardo da vinci', 'leonardodavinci'),
#  'B01NCRZVOJ': ('we were the lucky ones', 'weweretheluckyones'),
#  'B005H3FYR4': ('ghost in the wires', 'ghostinthewires'),
#  'B076DL3FF4': ('life reset: a litrpg novel', 'lifereset:alitrpgnovel'),
#  'B002VA8NLK': ('no country for old men', 'nocountryforoldmen'),
#  'B00MOVZC3S': ("not my father's son: a memoir", "notmyfather'sson:amemoir"),
#  'B0092T1AJK': ('the 100-year-old man who climbed out the window and disappeared',
#   'the100-year-oldmanwhoclimbedoutthewindowanddisappeared'),
#  'B002V5CMK8': ("captain's fury", "captain'sfury"),
#  'B00J54M7EY': ('i am pilgrim', 'iampilgrim'),
#  'B002V1CBTY': ('the concrete blonde', 'theconcreteblonde'),
#  'B01KP2IAP4': ('super powereds: year 3', 'superpowereds:year3'),
#  'B00CMUNXKK': ('dad is fat', 'dadisfat'),
#  'B004FG2QGQ': ('without remorse', 'withoutremorse'),
#  '1549129007': ('the law of innocence', 'thelawofinnocence'),
#  'B07BZV7FKK': ('kick ass with mel robbins', 'kickasswithmelrobbins'),
#  'B07D927TXD': ('last girl gone', 'lastgirlgone'),
#  '006289482X': ('the huntress', 'thehuntress'),
#  'B002V1LLP4': ('heart-shaped box', 'heart-shapedbox'),
#  'B08BW1VY1X': ('the meaning of mariah carey', 'themeaningofmariahcarey'),
#  'B0036NA8QO': ("first lord's fury", "firstlord'sfury"),
#  'B009SDRTNG': ('the forgotten', 'theforgotten'),
#  'B004YLIJH2': ('the third option', 'thethirdoption'),
#  'B002V5CSTS': ('act of treason', 'actoftreason'),
#  'B01KDCWFVQ': ("no man's land: john puller", "noman'sland:johnpuller"),
#  'B002V1BQ1I': ('when you are engulfed in flames',
#   'whenyouareengulfedinflames'),
#  'B00N58UDK6': ('critical failures', 'criticalfailures'),
#  'B007VEWUWY': ('the selection', 'theselection'),
#  'B002V0K23M': ('cutting for stone', 'cuttingforstone'),
#  'B011PVUGUG': ('make me', 'makeme'),
#  'B01BVV57I6': ("love warrior (oprah's book club: a memoir)",
#   "lovewarrior(oprah'sbookclub:amemoir)"),
#  'B088WZZX2W': ('the land: monsters', 'theland:monsters'),
#  'B013F5WEZK': ('how to talk to anyone', 'howtotalktoanyone'),
#  'B0799RFCCK': ('dungeon calamity', 'dungeoncalamity'),
#  'B002V8KU2W': ('god is not great', 'godisnotgreat'),
#  'B01AGM2XME': ('fear the survivors', 'fearthesurvivors'),
#  'B0777TY894': ('a gift of time', 'agiftoftime'),
#  'B00V75AIR2': ('down the rabbit hole', 'downtherabbithole'),
#  'B072PRFBPQ': ('building a storybrand', 'buildingastorybrand'),
#  'B0091J9AQQ': ('a walk in the woods', 'awalkinthewoods'),
#  'B009PSMCEU': ('dynasty of evil', 'dynastyofevil'),
#  'B00IGHD5EC': ('the storied life of a. j. fikry',
#   'thestoriedlifeofa.j.fikry'),
#  'B004G7VN04': ('guns, germs and steel', 'guns,germsandsteel'),
#  '0525638741': ('life will be the death of me', 'lifewillbethedeathofme'),
#  'B002V5D7IE': ("surely you're joking, mr. feynman!",
#   "surelyyou'rejoking,mr.feynman!"),
#  'B019HMZ2RM': ('hidden bodies', 'hiddenbodies'),
#  'B002V8HB8I': ('the energy bus', 'theenergybus'),
#  'B07J682QY2': ('kingdom of ash', 'kingdomofash'),
#  'B009KSQJ3U': ('gardens of the moon', 'gardensofthemoon'),
#  'B07WW91GLG': ('viva durant and the secret of the silver buttons',
#   'vivadurantandthesecretofthesilverbuttons'),
#  'B01EIL040M': ('killing the rising sun', 'killingtherisingsun'),
#  'B004KAVT1A': ('first grave on the right', 'firstgraveontheright'),
#  'B002V5CJDI': ('deception point: a novel', 'deceptionpoint:anovel'),
#  'B0145UL4MI': ('star wars: the force awakens', 'starwars:theforceawakens'),
#  '1980000174': ('dark age', 'darkage'),
#  'B07CLJYMN1': ('pieces of her', 'piecesofher'),
#  '1501217747': ('run away', 'runaway'),
#  'B0043BFH9G': ('the reversal', 'thereversal'),
#  'B0051QF7L0': ("napoleon hill's outwitting the devil",
#   "napoleonhill'soutwittingthedevil"),
#  'B00HQI67FG': ('terms of enlistment', 'termsofenlistment'),
#  'B004JPFTD0': ('memorial day', 'memorialday'),
#  'B002VA9GXE': ('dark lover', 'darklover'),
#  'B01BNVRCFA': ('born to run', 'borntorun'),
#  'B00MP2GM3U': ('the burning room', 'theburningroom'),
#  'B002UZKWLA': ('the green mile', 'thegreenmile'),
#  'B06X3QQTFH': ('will save the galaxy for food', 'willsavethegalaxyforfood'),
#  'B010PKSKBA': ('the dark forest', 'thedarkforest'),
#  'B01IQ1MFZ2': ('the trespasser', 'thetrespasser'),
#  'B07DKVMMRZ': ('the laws of human nature', 'thelawsofhumannature'),
#  'B00F52CCKE': ('go pro - 7 steps to becoming a network marketing professional',
#   'gopro-7stepstobecominganetworkmarketingprofessional'),
#  'B004HC9VOS': ('the lost gate', 'thelostgate'),
#  'B01CRMRCK4': ('the city of mirrors', 'thecityofmirrors'),
#  'B07D84P11M': ('super powereds: year 4', 'superpowereds:year4'),
#  'B002V1LAIM': ('extreme measures', 'extrememeasures'),
#  'B08DDCVRRC': ('thicker than water', 'thickerthanwater'),
#  'B00TTFI6VC': ('the dead key', 'thedeadkey'),
#  'B0036NAYIQ': ('jonathan strange & mr. norrell',
#   'jonathanstrange&mr.norrell'),
#  'B002V0KCYG': ("princeps' fury: codex alera", "princeps'fury:codexalera"),
#  'B0773VMSVH': ('killman creek', 'killmancreek'),
#  '1549143085': ('in pieces', 'inpieces'),
#  '1478999268': ('walk the wire', 'walkthewire'),
#  '0593154592': ('high achiever', 'highachiever'),
#  'B002VA9O4U': ('protect and defend', 'protectanddefend'),
#  'B006FX933G': ('locked on', 'lockedon'),
#  'B074F4DF5C': ('turtles all the way down', 'turtlesallthewaydown'),
#  'B07WK4PSH1': ('camp red moon', 'campredmoon'),
#  'B018EM84IA': ('the short drop', 'theshortdrop'),
#  'B01LWTY1ID': ('the duke and i', 'thedukeandi'),
#  'B01N0TLKIR': ('the final day', 'thefinalday'),
#  'B002VA35NG': ('the moon is a harsh mistress', 'themoonisaharshmistress'),
#  'B00XUTQ692': ("you're never weird on the internet (almost)",
#   "you'reneverweirdontheinternet(almost)"),
#  'B00G6ZP18Y': ('going home', 'goinghome'),
#  'B0058DSPPG': ("you're next", "you'renext"),
#  'B002V8MUYI': ('stranger in a strange land', 'strangerinastrangeland'),
#  'B009R8VOEC': ('the racketeer', 'theracketeer'),
#  'B014I51CFO': ('the bazaar of bad dreams', 'thebazaarofbaddreams'),
#  'B074CLGTFP': ('the girl who takes an eye for an eye',
#   'thegirlwhotakesaneyeforaneye'),
#  'B01CRN2KBY': ('star wars: life debt - aftermath',
#   'starwars:lifedebt-aftermath'),
#  'B07DKHSL3W': ('the infinite game', 'theinfinitegame'),
#  'B002UZN75I': ('their eyes were watching god', 'theireyeswerewatchinggod'),
#  'B005O1YEFW': ('the death cure', 'thedeathcure'),
#  '0062838180': ('before she knew him', 'beforesheknewhim'),
#  'B002V0TILE': ('children of the mind', 'childrenofthemind'),
#  'B01GGKQVFU': ('it ends with us', 'itendswithus'),
#  'B00BGTGSB4': ('the rithmatist', 'therithmatist'),
#  'B003TTX94I': ('medium raw', 'mediumraw'),
#  'B00K8CYDIA': ('one plus one', 'oneplusone'),
#  'B002V5BDXK': ("pandora's star", "pandora'sstar"),
#  'B00K8BXRM4': ('monster hunter nemesis', 'monsterhunternemesis'),
#  'B00ICRLMWI': ('flash boys', 'flashboys'),
#  'B08CMB2WMV': ('call me maybe', 'callmemaybe'),
#  'B00XIO0NV6': ('the cartel', 'thecartel'),
#  'B002V5BB5U': ("howl's moving castle", "howl'smovingcastle"),
#  'B0092POGIG': ('no easy day', 'noeasyday'),
#  'B01ITNQKC6': ('the dead zone', 'thedeadzone'),
#  'B07J1G9NY9': ('out of my mind', 'outofmymind'),
#  'B079G683TB': ('own the day, own your life', 'owntheday,ownyourlife'),
#  'B00ZAURNZA': ('dark disciple: star wars', 'darkdisciple:starwars'),
#  'B002V0RKRI': ('pursuit of honor', 'pursuitofhonor'),
#  'B005T3VNNQ': ('the litigators', 'thelitigators'),
#  'B00518NLX4': ('team of rivals', 'teamofrivals'),
#  'B01N1NU2X6': ('my not so perfect life', 'mynotsoperfectlife'),
#  'B002VA9JL8': ('death without company: a walt longmire mystery',
#   'deathwithoutcompany:awaltlongmiremystery'),
#  'B002V1AG7S': ('blood bound: mercy thompson', 'bloodbound:mercythompson'),
#  'B004VTB33E': ('executive power', 'executivepower'),
#  'B002V1BFI2': ('fight club', 'fightclub'),
#  'B00FFDMOUG': ('the circle', 'thecircle'),
#  'B01I28NTJU': ('hidden figures', 'hiddenfigures'),
#  'B009WU5YJ6': ('the lions of lucerne', 'thelionsoflucerne'),
#  'B074WGZ4DT': ('sweet tea and sympathy', 'sweetteaandsympathy'),
#  'B00C6LVQ0E': ("let's explore diabetes with owls",
#   "let'sexplorediabeteswithowls"),
#  'B01FN88BHC': ('anna karenina', 'annakarenina'),
#  'B081HG2XXH': ('peter pan', 'peterpan'),
#  'B01BI1X19Q': ('fire touched', 'firetouched'),
#  '1690582162': ('the housekeeper', 'thehousekeeper'),
#  '0062906402': ('over the top', 'overthetop'),
#  'B004YLAC4A': ('separation of power', 'separationofpower'),
#  'B007NLYK0A': ('the stranger beside me', 'thestrangerbesideme'),
#  'B079P6VFH1': ('the coddling of the american mind',
#   'thecoddlingoftheamericanmind'),
#  'B00IIW125Y': ('the atlantis gene', 'theatlantisgene'),
#  'B002UZYUNQ': ('the audacity of hope', 'theaudacityofhope'),
#  'B0714K8NSF': ('capital gaines', 'capitalgaines'),
#  'B01J8RBULS': ('tier one', 'tierone'),
#  'B07C51WW3Q': ('legacy of the fallen', 'legacyofthefallen'),
#  'B00CDWRXJE': ('the 5th wave', 'the5thwave'),
#  'B00KQMVVXM': ('what i know for sure', 'whatiknowforsure'),
#  'B07N93P28H': ('house of assassins', 'houseofassassins'),
#  'B077BPKPZQ': ('the culture code', 'theculturecode'),
#  'B002V1AE98': ('the brass verdict', 'thebrassverdict'),
#  'B07FTDBKGZ': ('master & apprentice (star wars)',
#   'master&apprentice(starwars)'),
#  'B00VSELTJS': ('china rich girlfriend', 'chinarichgirlfriend'),
#  'B002VA3QZ8': ('city of ashes', 'cityofashes'),
#  'B00I2WV0WA': ('night broken', 'nightbroken'),
#  'B009M8YHCI': ('reflected in you', 'reflectedinyou'),
#  'B07GHB5YQN': ('love and other wild things', 'loveandotherwildthings'),
#  'B002UZLF2U': ('rendezvous with rama', 'rendezvouswithrama'),
#  'B005KBQQZC': ('helter skelter', 'helterskelter'),
#  'B002VA9CAQ': ('the last colony', 'thelastcolony'),
#  'B002V8MG06': ('redeeming love', 'redeeminglove'),
#  'B06Y5SDTGJ': ('the rise and fall of d.o.d.o.', 'theriseandfallofd.o.d.o.'),
#  '1772309117': ('six sacred swords', 'sixsacredswords'),
#  'B0765CKNLF': ('blackwater: the complete saga', 'blackwater:thecompletesaga'),
#  'B002UZKK2G': ('the sword of shannara: the shannara series',
#   'theswordofshannara:theshannaraseries'),
#  'B0195LQYF4': ('the book on rental property investing',
#   'thebookonrentalpropertyinvesting'),
#  'B086WMZ9WR': ('cryptonomicon', 'cryptonomicon'),
#  'B00937SXLO': ('call the midwife', 'callthemidwife'),
#  'B07KWGC7S1': ('chase darkness with me', 'chasedarknesswithme'),
#  'B00HNXV0R4': ('hollow city', 'hollowcity'),
#  'B087D5ZZ8Z': ('forget nothing', 'forgetnothing'),
#  'B00A8K96MK': ('shadow and bone', 'shadowandbone'),
#  'B002V1A68M': ('the clan of the cave bear', 'theclanofthecavebear'),
#  'B002V8L5FS': ("childhood's end", "childhood'send"),
#  'B0042YZ6JA': ('the power', 'thepower'),
#  'B0041NZRDC': ('the happiness advantage', 'thehappinessadvantage'),
#  'B003LZ8PMG': ('the blade itself', 'thebladeitself'),
#  'B002V0QCP4': ('the power of the dog', 'thepowerofthedog'),
#  'B00JLOJ04I': ('bird box', 'birdbox'),
#  'B075XR9V8S': ('end game', 'endgame'),
#  'B004I6ZR78': ('rainbow six', 'rainbowsix'),
#  'B01MTC3V6Y': ('get well soon', 'getwellsoon'),
#  'B0045KX2HY': ('the haunting of hill house', 'thehauntingofhillhouse'),
#  'B0744MBFH3': ('monster hunter siege', 'monsterhuntersiege'),
#  'B00K5SCCXU': ('the disaster artist', 'thedisasterartist'),
#  'B00482T0D4': ('plum island: booktrack edition',
#   'plumisland:booktrackedition'),
#  'B00J5SHJMK': ('as a man thinketh', 'asamanthinketh'),
#  'B0037XXKYA': ('abraham lincoln: vampire hunter',
#   'abrahamlincoln:vampirehunter'),
#  'B078Z3T5RB': ('everybody, always', 'everybody,always'),
#  'B002VAGMJA': ("the omnivore's dilemma", "theomnivore'sdilemma"),
#  '0593167171': ('the splendid and the vile', 'thesplendidandthevile'),
#  '1549117351': ("summer of '69", "summerof'69"),
#  '1250317029': ('the path made clear', 'thepathmadeclear'),
#  'B079MHWLT2': ('death of mrs. westaway', 'deathofmrs.westaway'),
#  'B01JQGTYKA': ('not alone', 'notalone'),
#  'B002V5BLEQ': ('memoirs of a geisha', 'memoirsofageisha'),
#  'B07CJ4C449': ('super sales on super heroes', 'supersalesonsuperheroes'),
#  'B002V0QO5W': ('never let me go', 'neverletmego'),
#  'B07B8WTK8G': ('a polaroid guy in a snapchat world',
#   'apolaroidguyinasnapchatworld'),
#  '1508287694': ('the family upstairs', 'thefamilyupstairs'),
#  'B082YHZPTY': ('house of earth and blood', 'houseofearthandblood'),
#  'B07BYKYVNC': ('out of spite, out of mind', 'outofspite,outofmind'),
#  '1974927148': ('missing molly', 'missingmolly'),
#  '0062957864': ('nothing to see here', 'nothingtoseehere'),
#  '0062824643': ('cemetery road', 'cemeteryroad'),
#  'B084GYSS73': ('the decision', 'thedecision'),
#  'B002V1NYEK': ('into the wild', 'intothewild'),
#  'B002V8MYYE': ('artemis fowl', 'artemisfowl'),
#  'B003NTPCVM': ('royal assassin', 'royalassassin'),
#  'B00RKMHUYU': ('the revenant', 'therevenant'),
#  'B01MRSYSI4': ("empire's end: aftermath", "empire'send:aftermath"),
#  'B002V9ZFX0': ('blade runner', 'bladerunner'),
#  'B077F6TSQ4': ('before the storm', 'beforethestorm'),
#  'B00JEKVZKQ': ('dust world', 'dustworld'),
#  'B072F77W4D': ('enemy of the state', 'enemyofthestate'),
#  'B007BR5KZA': ('the wonderful wizard of oz', 'thewonderfulwizardofoz'),
#  'B00BQYO50K': ('killing jesus', 'killingjesus'),
#  'B07BGDSPR9': ('head on (narrated by wil wheaton)',
#   'headon(narratedbywilwheaton)'),
#  'B07D3C3GJT': ("galaxy's edge, part ii", "galaxy'sedge,partii"),
#  'B00VVZPEX6': ('a darker shade of magic', 'adarkershadeofmagic'),
#  'B002V9Z4SQ': ('bone crossed', 'bonecrossed'),
#  'B0713X72LX': ('the breakdown', 'thebreakdown'),
#  'B00BWA3S3S': ('aristotle and dante discover the secrets of the universe',
#   'aristotleanddantediscoverthesecretsoftheuniverse'),
#  'B00E7ZBDLY': ('never go back', 'nevergoback'),
#  'B0049D0MJ8': ('and one last thing...', 'andonelastthing...'),
#  '0593289641': ('the evening and the morning', 'theeveningandthemorning'),
#  '1549157736': ('troubled blood', 'troubledblood'),
#  'B07D3B4CSY': ('the kiss quotient', 'thekissquotient'),
#  '0593102819': ('dooku: jedi lost (star wars)', 'dooku:jedilost(starwars)'),
#  'B06VV7NQJ5': ('forging hephaestus', 'forginghephaestus'),
#  'B0771WH7Q7': ('sometimes i lie', 'sometimesilie'),
#  'B002VAA7UU': ('across the nightingale floor', 'acrossthenightingalefloor'),
#  '0062868071': ('the end is always near', 'theendisalwaysnear'),
#  'B002V8MOTY': ('iron kissed', 'ironkissed'),
#  'B00O4IDJDE': ('tarkin: star wars', 'tarkin:starwars'),
#  'B00LWEW8RG': ('gray mountain', 'graymountain'),
#  'B00487NTAO': ('full dark, no stars', 'fulldark,nostars'),
#  'B0146ZSJCA': ("a warrior's path", "awarrior'spath"),
#  'B002V1NHU6': ('mere christianity', 'merechristianity'),
#  'B002V8MK1G': ('the woods', 'thewoods'),
#  'B002VA9TI6': ('thirteen reasons why', 'thirteenreasonswhy'),
#  'B071ZSYCXB': ('peak performance', 'peakperformance'),
#  'B07D2HN6PP': ('the hunt for red october', 'thehuntforredoctober'),
#  'B00FEFE4XK': ('the complete sherlock holmes', 'thecompletesherlockholmes'),
#  'B009WROSXW': ('die trying', 'dietrying'),
#  'B01AAXYDP4': ('the princess diarist', 'theprincessdiarist'),
#  'B004QPJZW4': ('the dragon factory', 'thedragonfactory'),
#  'B07YXCPNX4': ('climbing with mollie', 'climbingwithmollie'),
#  'B073FWSV9S': ('the light of life', 'thelightoflife'),
#  'B002V9ZAXK': ('blood of the fold', 'bloodofthefold'),
#  'B00S5ABNX0': ('well fed', 'wellfed'),
#  'B004QDTA9Y': ('the selfish gene', 'theselfishgene'),
#  'B07C2Z1XKL': ('the bone farm', 'thebonefarm'),
#  'B00M8HL81I': ('the dragons of dorcastle', 'thedragonsofdorcastle'),
#  'B008KP5K5W': ('the 21 irrefutable laws of leadership, 10th anniversary edition',
#   'the21irrefutablelawsofleadership,10thanniversaryedition'),
#  'B06XRQK92M': ('awaken online: precipice', 'awakenonline:precipice'),
#  'B0198R8TJO': ('the chimes', 'thechimes'),
#  'B014X1ECK0': ('her final breath', 'herfinalbreath'),
#  'B002V5H4II': ('lost light', 'lostlight'),
#  '147897835X': ('the burning white', 'theburningwhite'),
#  'B078XK2T1T': ('so you want to talk about race', 'soyouwanttotalkaboutrace'),
#  'B01IAIZFBW': ('present over perfect', 'presentoverperfect'),
#  'B079VPVBSW': ('red war', 'redwar'),
#  'B0764LBS4B': ('horus rising', 'horusrising'),
#  'B002V8KWN4': ('city of glass', 'cityofglass'),
#  'B009G44NK4': ('killing kennedy', 'killingkennedy'),
#  'B002V8HNWC': ('mating in captivity', 'matingincaptivity'),
#  'B005S44J2I': ('the hiding place', 'thehidingplace'),
#  'B07CB8F2Q9': ('the other woman', 'theotherwoman'),
#  'B00WJ23VAS': ('the man in the high castle', 'themaninthehighcastle'),
#  'B0813XPXHB': ('pont neuf', 'pontneuf'),
#  'B002V8HA9I': ('blood work', 'bloodwork'),
#  'B0052OUFO0': ('state of wonder', 'stateofwonder'),
#  'B019HMBEWE': ('needful things', 'needfulthings'),
#  'B01LWS6XM0': ('a study in scarlet women', 'astudyinscarletwomen'),
#  'B076Y2FWGY': ('morningwood: everybody loves large chests (vol.1)',
#   'morningwood:everybodyloveslargechests(vol.1)'),
#  'B01N49H59Z': ('the complete guide to fasting', 'thecompleteguidetofasting'),
#  'B004Q7FZPS': ('john dies at the end', 'johndiesattheend'),
#  'B075NG21VQ': ('hell to pay', 'helltopay'),
#  'B002VACOB0': ('john adams', 'johnadams'),
#  'B007T7U0RK': ("let's pretend this never happened",
#   "let'spretendthisneverhappened"),
#  'B01JKG9FMS': ('tom clancy true faith and allegiance',
#   'tomclancytruefaithandallegiance'),
#  'B004WPQ3V4': ('in the garden of beasts', 'inthegardenofbeasts'),
#  'B06Y2GKZ39': ('goodbye, things', 'goodbye,things'),
#  'B0045VT4NY': ('worth dying for', 'worthdyingfor'),
#  'B003UC45I8': ('the word of promise complete audio bible: nkjv',
#   'thewordofpromisecompleteaudiobible:nkjv'),
#  'B00EFB89SU': ('the house of hades', 'thehouseofhades'),
#  'B002V8DLIM': ("shadow's edge", "shadow'sedge"),
#  'B07HYBGK8D': ('life reset: evp (environment vs. player)',
#   'lifereset:evp(environmentvs.player)'),
#  'B004966PJQ': ('sex at dawn', 'sexatdawn'),
#  'B0051JGU1S': ('interview with the vampire', 'interviewwiththevampire'),
#  'B003XWVC0E': ("assassin's quest", "assassin'squest"),
#  'B016N7P4OU': ('best served cold', 'bestservedcold'),
#  'B07DKGR2S4': ('the witch elm', 'thewitchelm'),
#  'B003C1UL94': ('silver borne', 'silverborne'),
#  'B014WY3T34': ('the death of dulgath', 'thedeathofdulgath'),
#  'B00RM5GOJW': ('the misadventures of awkward black girl',
#   'themisadventuresofawkwardblackgirl'),
#  'B004Q7LAGG': ('star wars: the old republic: deceived',
#   'starwars:theoldrepublic:deceived'),
#  'B0032YXMP6': ('beyond the shadows: night angel trilogy',
#   'beyondtheshadows:nightangeltrilogy'),
#  'B07235B2FT': ('way of the wolf', 'wayofthewolf'),
#  'B002V8MU8E': ('maisie dobbs', 'maisiedobbs'),
#  'B003XET1PU': ('clockwork angel', 'clockworkangel'),
#  'B002UZZ1DE': ('bag of bones', 'bagofbones'),
#  'B07CZQPDMM': ('season of storms', 'seasonofstorms'),
#  'B003O5FNTG': ('delivering happiness', 'deliveringhappiness'),
#  'B007SXGJ9S': ('the wind through the keyhole', 'thewindthroughthekeyhole'),
#  'B002VACD3Y': ('forever odd', 'foreverodd'),
#  'B002UZKX5K': ('oryx and crake', 'oryxandcrake'),
#  'B005VGLIC2': ('the winds of war', 'thewindsofwar'),
#  'B004BU7RH4': ('the practicing mind', 'thepracticingmind'),
#  'B01LW7OXWP': ("death's end", "death'send"),
#  'B07KG5FV3B': ('dodge & twist', 'dodge&twist'),
#  'B0030H777E': ("a people's history of the united states",
#   "apeople'shistoryoftheunitedstates"),
#  'B005Z3FIS6': ('the next always', 'thenextalways'),
#  '0062945068': ('the right side of history', 'therightsideofhistory'),
#  'B005BTZ6I6': ('rules of civility', 'rulesofcivility'),
#  '179712319X': ('the last thing he told me', 'thelastthinghetoldme'),
#  'B002V1CM4I': ('kindness goes unpunished: a walt longmire mystery',
#   'kindnessgoesunpunished:awaltlongmiremystery'),
#  '1977385885': ('dungeon desolation', 'dungeondesolation'),
#  'B004O416JW': ('river marked', 'rivermarked'),
#  'B003RD102O': ('star wars: the old republic: fatal alliance',
#   'starwars:theoldrepublic:fatalalliance'),
#  'B00FOX9E2S': ('with the old breed', 'withtheoldbreed'),
#  'B0149LZ5ZK': ('library of souls', 'libraryofsouls'),
#  'B07L44RHCT': ('the scholar', 'thescholar'),
#  'B083L91MGM': ('one minute out', 'oneminuteout'),
#  'B002V8MREQ': ('the sociopath next door', 'thesociopathnextdoor'),
#  '1250219345': ('under currents', 'undercurrents'),
#  'B009XEKR3O': ("the emperor's soul", "theemperor'ssoul"),
#  '1549184466': ('the summer house', 'thesummerhouse'),
#  'B01CIRNDH4': ('the fireman', 'thefireman'),
#  'B00PRAGG2Y': ('the last kingdom', 'thelastkingdom'),
#  'B003L8WQSC': ('the desert spear', 'thedesertspear'),
#  'B002V0TMT2': ('shadow of the hegemon', 'shadowofthehegemon'),
#  'B002V5GXU8': ('city of bones', 'cityofbones'),
#  'B08HNG2KC7': ('disloyal: a memoir', 'disloyal:amemoir'),
#  'B016N9U1XW': ('the silmarillion', 'thesilmarillion'),
#  'B002V1J8OU': ('the fire next time', 'thefirenexttime'),
#  'B002VA9J2M': ('temple of the winds', 'templeofthewinds'),
#  'B01LDRPUVM': ('a quiet life in the country', 'aquietlifeinthecountry'),
#  '1501903403': ('this tender land', 'thistenderland'),
#  'B00YNFR23G': ('killing reagan', 'killingreagan'),
#  'B01DJJB5U2': ('stuck-up suit', 'stuck-upsuit'),
#  'B00839242W': ('love does', 'lovedoes'),
#  'B00ELMX3L6': ('the signature of all things', 'thesignatureofallthings'),
#  '059333972X': ('the sentinel', 'thesentinel'),
#  'B00NI6ULWA': ('the blood of olympus', 'thebloodofolympus'),
#  'B00SSAW2P0': ('reasonable doubt', 'reasonabledoubt'),
#  '1772308641': ('court wizard', 'courtwizard'),
#  'B002VA3KG8': ('atlas shrugged', 'atlasshrugged'),
#  'B0788BD32G': ('battle mage', 'battlemage'),
#  ...}

# %% [markdown]
# ### title to tweet function

# %%
# define function that loops through dictionary and tweetes to check if title exists in tweet
def getASIN(x):
    for key, values in cat_dict.items():
        for value in values:
            if value in x:
                return key
    else:
        return np.nan

# %% [markdown]
# #### test the function on a small mock dataset to ensure it works properly

# %%
# load test tweets

df = pd.read_csv('C:/Users/creeg/Downloads/full_tweet_set.csv')
# Out:
# C:\Users\creeg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (0,1,2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# running function against a small sample of fake tweets to confirm it works appropriately 
test_df = df[:1000]

# %%
test_df.head()
# Out:
#                     Datetime             Tweet Id  \
# 0  2022-03-23 23:50:07+00:00  1506780360834748419
# 1  2022-03-23 23:15:05+00:00  1506771544600719367
# 2  2022-03-23 23:00:01+00:00  1506767752152985610
# 3  2022-03-23 22:52:17+00:00  1506765808218820610
# 4  2022-03-23 21:44:13+00:00  1506748679109160969
#
#                                                 Text         Username  \
# 0  Off to a great start\n\n#TheSevenHusbandsOfEve...     actuallydana
# 1  Enoch by Jarrod Edge #christian #scifi\n"Proph...  IAN_AuthorPromo
# 2  Soooooo, I’m on 📷TikTok: https://t.co/DyaEldN1...  LovinSunshine97
# 3  GUYS!\nI just hit 2K on my BookTok account 😭💖💖...   adorkablebooks
# 4  Thank you to @UnionSqandCo for believing in Ke...  themelissablair
#
#     hashtag
# 0  #booktok
# 1  #booktok
# 2  #booktok
# 3  #booktok
# 4  #booktok

# %%
tweets = test_df['Text'].tolist()

# %%
tweets[:2]
# Out:
# ['Off to a great start\n\n#TheSevenHusbandsOfEvelynHugo #BookTok #EvelynHugo https://t.co/1VW70greWt',
#  'Enoch by Jarrod Edge #christian #scifi\n"Prophecy of the Seventh Elizabeth Series"\nhttps://t.co/XbYSQROtRW\n#amreading @e7prophecy \n#goodreads #booktok\n#iartg #ian1 #asmsg https://t.co/A05GiULguY']

# %%
matched = {
    # For each key in the dictionary, create a new tuple
    key: tuple(
    # For the tweets, if there exists a string in the original tuple value that is a substring of that element, then retain it in the result.    
        filter(lambda x: any(substr in x for substr in value), tweets))
        for key, value in cat_dict.items()
}

# filter out all of the key-value pairs that have empty tuples for values using a dictionary comprehension. We could condense into one line, but I think it becomes pretty unreadable
result = {key: value for key, value in matched.items() if value != ()}

print(result)
# Out:
# {'B0099RKI5W': ('Thranduil daddy update part 12. Final part of the series! Merch coming soon. #lotr #lotrtok #lordoftherings #lordoftheringstiktok #thranduil #thranduiltok #thehobbit #hobbit #bodiceripper #booktok https://t.co/46fEVxnhOm',), 'B007EZKMP2': ('okay so about the #booktok im new in this sphere so idk what to say so i can find some mutuals here. i write sometimes, mostly fan fictions. dont have any ready project in the moment, just drafts\nfavourite book: the song of achilles 🎈\njust started reading books and i write more', '“Tell me again.” \n\n#thesongofachilles #madelinemiller #booktwt #booktok https://t.co/oHAfnCM2om'), 'B00WRHY15Y': ('About to start this one; keep hearing good stuff about it. So…we’ll see 📖 \n\n#acourtofthornsandroses #booktwt #booktok https://t.co/50bN4Ejekd',), '059321000X': ('When you come back to work after a week off and there are so many pretty things waiting for you ♥️ #waterstones #waterstonesbooksellers #books#bookstagram #booktok #newbooks #bibliophile https://t.co/qxVzOGTC44',), 'B002VA9X9Q': ('After watching over this world for millennia, a girl wandering in the woods should have been of no interest to me. But the moment I saw her bathing in a stream, I knew Emma was mine.\n\nA beast must claim his mate.\n\n#booktok #romance\n\nhttps://t.co/3YHPih4GuW https://t.co/1al0qkvSfj', 'After watching over this world for millennia, a girl wandering in the woods should have been of no interest to me. But the moment I saw her bathing in a stream, I knew Emma was mine.\n\nA beast must claim his mate.\n\n#booktok #romance\n\nhttps://t.co/3YHPih4GuW https://t.co/fAgBeBs7HG', 'After watching over this world for millennia, a girl wandering in the woods should have been of no interest to me. But the moment I saw her bathing in a stream, I knew Emma was mine.\n\nA beast must claim his mate.\n\n#booktok #romance\n\nhttps://t.co/3YHPih4GuW https://t.co/wjeAZBJLFE', 'After watching over this world for millennia, a girl wandering in the woods should have been of no interest to me. But the moment I saw her bathing in a stream, I knew Emma was mine.\n\nA beast must claim his mate.\n\n#booktok #romance\n\nhttps://t.co/3YHPih4GuW https://t.co/3yWQu2G6TZ'), '125077795X': ('Has anyone read " the invisible life of addie larue" ? \nTell me that it has a good ending or I won\'t read it! \n\n#BookTwitter #booktok #bookstagram #books #book #WritingCommunity #writers #TheInvisibleLifeofAddieLaRue https://t.co/WHJeU2b952', 'Should I read The Invisible Life of Addie LaRue or All of My Perfects by Colleen Hoover??? #allofmyperfects #theinvisiblelifeofaddielarue #booktwt #booktok #readers'), 'B014JWSCWW': ('I see meeeee not only once BUT TWICE!\n\n#onceuponabrokencrown #SavageBloodlineBoxset  #newrelease  #newreels #booktok https://t.co/g2XmwnBDKF', 'That only seemed to upset the fans further who have gone and are one-starring the book and doxing + sending death threats to the author.\xa0#booktok #booktwt #jla #bloodandash https://t.co/72affsiSoz', '@JamesKennardo https://t.co/OfKCh9Y32t I started having reoccurring vivid dreams of a young man in his teens. He seemed so familiar to me, like I have known him for lifetimes. Yet I have never met him, or have I? #booktok #SerialFiction #RomCom #bookstagram #ReadMe ch.1-3 #Free +200 free tokens', '@carlvdupre https://t.co/Om0QvxYs0j I started having reoccurring vivid dreams of a young man in his teens. He seemed so familiar to me, like I have known him for lifetimes. Yet I have never met him, or have I? #booktok #SerialFiction #Vella #bookstagram #ReadMe ch.1-3 #Free +200 free tokens'), 'B013XNVR3E': ('“Is there a word for what happens after your sworn nemesis let’s you into their room and tells you their secrets?” Yes, honey, it’s called the rivals to lovers trope, keep up #booktok',), 'B071GS25H4': ('For Justus Reynolds, Friday nights are about the clubs, dancing, drinking, hooking up...and murder.\nhttps://t.co/NV6n5t9o2Y\nCan the young office clerk find out what happened ...

# %%
test_df['ASIN'] = test_df['Text'].apply(getASIN)

# %%
test_df.head(10)
# crawdads = B07FSNSLZ1
# can't hurt me = B07KKMNZCH
# name of the wind = B002UZMLXM
# Out:
#                     Datetime      Tweet Id  \
# 0  2022-03-23 23:50:07+00:00  1.506780e+18
# 1  2022-03-23 23:15:05+00:00  1.506770e+18
# 2  2022-03-23 23:00:01+00:00  1.506770e+18
# 3  2022-03-23 23:00:01+00:00  1.506770e+18
# 4  2022-03-23 23:00:01+00:00  1.506770e+18
# 5  2022-03-23 23:00:01+00:00  1.506770e+18
#
#                                                 Text         Username  \
# 0  where the crawdads sing was a great book, name...     actuallydana
# 1                       i love reading can't hurt me  IAN_AuthorPromo
# 2    reading the name of the wind right now, so good  LovinSunshine97
# 3                                          xxxxxxxxx  LovinSunshine97
# 4                            reading #agameofthrones  LovinSunshine97
# 5                             I love reading so much  LovinSunshine97
#
#     hashtag        ASIN
# 0  #booktok  B07FSNSLZ1
# 1  #booktok  B07KKMNZCH
# 2  #booktok  B002UZMLXM
# 3  #booktok         NaN
# 4  #booktok  B002UZZ93G
# 5  #booktok         NaN

# %%
cat_dict.get('B002UZZ93G')
# Out:
# ('a game of thrones', 'agameofthrones')

# %% [markdown]
# ### load & cleaning tweet data

# %%
df_tweets = pd.read_csv('/Users/Mary/Desktop/NLP/Group Project/full_tweet_set.csv')
# Out:
# /Users/Mary/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (0,1,2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_tweets['Text'] = df_tweets['Text'].astype('string')
df_tweets['Tweet Id'] = df_tweets['Tweet Id'].astype('string')
df_tweets['Username'] = df_tweets['Username'].astype('string')
df_tweets['hashtag'] = df_tweets['hashtag'].astype('string')

# %%
print(len(df_tweets))
df_tweets.drop_duplicates(subset='Tweet Id',inplace=True)
print(len(df_tweets))
# Out:
# 168435948
# 1276598

# %%
print(len(df_tweets))
df_tweets.dropna(subset=['Text'],inplace=True)
print(len(df_tweets))
# Out:
# 1276598
# 1276597

# %%
df_tweets.head()
# Out:
#                     Datetime             Tweet Id  \
# 0  2022-03-23 23:50:07+00:00  1506780360834748419
# 1  2022-03-23 23:15:05+00:00  1506771544600719367
# 2  2022-03-23 23:00:01+00:00  1506767752152985610
# 3  2022-03-23 22:52:17+00:00  1506765808218820610
# 4  2022-03-23 21:44:13+00:00  1506748679109160969
#
#                                                 Text         Username  \
# 0  Off to a great start
#
# #TheSevenHusbandsOfEvely...     actuallydana
# 1  Enoch by Jarrod Edge #christian #scifi
# "Prophe...  IAN_AuthorPromo
# 2  Soooooo, I’m on 📷TikTok: https://t.co/DyaEldN1...  LovinSunshine97
# 3  GUYS!
# I just hit 2K on my BookTok account 😭💖💖 ...   adorkablebooks
# 4  Thank you to @UnionSqandCo for believing in Ke...  themelissablair
#
#     hashtag
# 0  #booktok
# 1  #booktok
# 2  #booktok
# 3  #booktok
# 4  #booktok

# %%
# make tweets lowercase for string matching
df_tweets['Text'] = df_tweets['Text'].str.lower() #.astype('unicode')

# %%
df_tweets_sample = df_tweets.head(100)

# %% [markdown]
# ### run the title to tweet function over tweet dataset

# %%
df_tweets_sample['ASIN'] = df_tweets_sample['Text'].apply(getASIN)
# Out:
# /var/folders/cv/l7wnv7t94vvfyk2t65yjhyy80000gn/T/ipykernel_8430/1168861302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tweets_sample['ASIN'] = df_tweets_sample['Text'].apply(getASIN)

# %%
df_tweets_sample.head()
# Out:
#                     Datetime             Tweet Id  \
# 0  2022-03-23 23:50:07+00:00  1506780360834748419
# 1  2022-03-23 23:15:05+00:00  1506771544600719367
# 2  2022-03-23 23:00:01+00:00  1506767752152985610
# 3  2022-03-23 22:52:17+00:00  1506765808218820610
# 4  2022-03-23 21:44:13+00:00  1506748679109160969
#
#                                                 Text         Username  \
# 0  off to a great start
#
# #thesevenhusbandsofevely...     actuallydana
# 1  enoch by jarrod edge #christian #scifi
# "prophe...  IAN_AuthorPromo
# 2  soooooo, i’m on 📷tiktok: https://t.co/dyaeldn1...  LovinSunshine97
# 3  guys!
# i just hit 2k on my booktok account 😭💖💖 ...   adorkablebooks
# 4  thank you to @unionsqandco for believing in ke...  themelissablair
#
#     hashtag        ASIN
# 0  #booktok  B072359S7K
# 1  #booktok  B0064RTUO0
# 2  #booktok  B07L5YVGDC
# 3  #booktok         NaN
# 4  #booktok  B002V1POWK

# %%
df_tweets['ASIN'] = df_tweets['Text'].apply(getASIN)

# %%
df_tweets.head()

# %%
# count number of tweets with no ASIN assigned 
# i.e. do not contain a title 
df_tweets['ASIN'].isna().sum()

# %%
df_tweets.head()

# %%
pd.set_option('display.max_colwidth', None)
df_tweets[:1]['Text']

# %%
df_tweets.to_csv('/Users/Mary/Desktop/NLP/Group Project/tweets_with_asin.csv')

# %%
df_tweets_no_null = df_tweets.dropna(subset=['ASIN'])

# %%
len(df_tweets_no_null)

# %%
# group tweets by asin & count number of occurrences 
asin_cts = df_tweets_no_null.groupby(['ASIN']).size().reset_index()

# %%
# sort for top 10 asins appearing in tweets
asin_cts.sort_values(0, ascending=False).head()

# %%
cat_dict.get('B0048G19IE')

# %%
df_tweets.dtypes

# %%
df_tweets.head()
